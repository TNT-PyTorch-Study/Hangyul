# %% [markdown]
# # 0.make folders and data downloads

# %%
import os
import urllib.request
import zipfile
import tarfile

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/[TNT] 21-winter Pytorch/pytorch_advanced-kr/5_gan_generation')

# %%
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.0.2

# %%
# AWS의 AMI에서 sklern의 version이 0.20보다 낮은 경우에는 버전을 업데이트
# pip install -U scikit-learn

# %%
# MNIST의 필기체 숫자 화상을 다운로드
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, data_home="./data/", as_frame=False)

# %%
X = mnist.data
y = mnist.target

# %%
type(X)
# Out:
# numpy.ndarray

# %%
# MNIST의 데이터 첫 번째를 시각화
plt.imshow(X[0].reshape(28, 28), cmap='gray')
print("이 화상 데이터의 라벨은 {}입니다".format(y[0]))
# Out:
# 이 화상 데이터의 라벨은 5입니다

# %%
# "data" 폴더의 아래에 "img_78" 폴더 생성 
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNIST에서 숫자7, 8의 화상만 "img_78" 폴더에 이미지로 저장
count7=0
count8=0
max_num=200  # 이미지는 200장씩 작성

for i in range(len(X)):
    
    # image7 작성
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 이미지를 28×28의 형태로 변경
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 이미지를 PIL으로
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64로 확대
        pil_img_f.save(file_path)  # 저장
        count7+=1 
    
    # image8 작성
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 화상을 28×28의 형태로 변경
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 화상을 PIL으로
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64로 확대
        pil_img_f.save(file_path)  # 저장
        count8+=1

# %% [markdown]
# # 1.DCGAN

# %%
# 패키지 import
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# ## 1-1. Transposed Convolution

# %%
input = torch.tensor([[[[1., 1.], [2., 2.]]]])
print("입력 데이터")
print(input)
print("-----")

print("일반 합성곱")
m = nn.Conv2d(1, 1, 2, stride=1, bias=False)
m.weight[0, 0, 0, 0] = 1
m.weight[0, 0, 0, 1] = 2
m.weight[0, 0, 1, 0] = 3
m.weight[0, 0, 1, 1] = 4
print("커널")
print(m.weight)
print("출력")
print(m(input))

print("-----")
print("전치 합성곱")
m = nn.ConvTranspose2d(1, 1, 2, stride=1, bias=False)
m.weight[0, 0, 0, 0] = 1
m.weight[0, 0, 0, 1] = 2
m.weight[0, 0, 1, 0] = 3
m.weight[0, 0, 1, 1] = 4
print("커널")
print(m.weight)
print("출력")
print(m(input))

# %%
a = torch.rand((1,1,2,3)).view(1,1,6) # 배치, 채널 ,행, 렬
b = a.transpose(1,2).matmul(a) # 대칭행렬
b
# Out:
# tensor([[[0.0008, 0.0116, 0.0075, 0.0106, 0.0017, 0.0203],
#          [0.0116, 0.1615, 0.1044, 0.1474, 0.0234, 0.2816],
#          [0.0075, 0.1044, 0.0675, 0.0953, 0.0151, 0.1821],
#          [0.0106, 0.1474, 0.0953, 0.1344, 0.0214, 0.2569],
#          [0.0017, 0.0234, 0.0151, 0.0214, 0.0034, 0.0408],
#          [0.0203, 0.2816, 0.1821, 0.2569, 0.0408, 0.4909]]])

# %%
a
# Out:
# tensor([[[0.0290, 0.4019, 0.2598, 0.3666, 0.0583, 0.7006]]])

# %%
a.transpose(1,2)
# Out:
# tensor([[[0.0290],
#          [0.4019],
#          [0.2598],
#          [0.3666],
#          [0.0583],
#          [0.7006]]])

# %%
# 파이토치에서는 
# 1차원 (행)
# 2차원 (열, 행)
# 3차원 (채널, 열 , 행)
# 4차원 (배치, 채널, 열, 행)

m1 = nn.Softmax(dim = 0) # 3차원 -> 채널수직방향으로 softmax -> 다 1로 나옴
m2 = nn.Softmax(dim = 1) # 3차원 -> 열 방향으로 softmax 
m3 = nn.Softmax(dim = 2) # 3차원 -> 행 방향으로 softmax

m4 = nn.Softmax(dim = -1) #행방향 -> 행 방향으로 softmax
m5 = nn.Softmax(dim = -2) #행방향 -> 열 방향으로 softmax 
m6 = nn.Softmax(dim = -3) #행방향 -> 채널수직방향으로 softmax -> 다 1로 나옴

# %% [markdown]
# ## 1-2. Generator

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8,
                               kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 흑백 이미지이므로 출력 채널은 1

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 동작 확인
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 난수 입력
input_z = torch.randn(1, 20)

# 텐서 크기를 (1, 20, 1, 1)으로 변형
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 가짜 이미지 출력
fake_images = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# ## 1-3. Discriminator

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 흑백 이미지이므로 입력 채널은 1

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 동작 확인
D = Discriminator(z_dim=20, image_size=64)

# 가짜 이미지 생성
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 가짜 이미지를 D에 입력
d_out = D(fake_images)

# 출력 d_out에 Sigmoid를 곱해 0에서 1로 변환
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.4969]]]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# ## 1-4. GAN Loss function

# %%
'''
D의 오차함수의 이미지 구현
maximize log(D(x)) + log(1 - D(G(z)))

*** x가 정의되지 않았으므로, 에러!!!!
'''


# 정답 라벨
mini_batch_size = 2
label_real = torch.full((mini_batch_size,), 1)

# 가짜 라벨
label_fake = torch.full((mini_batch_size,), 0)

# 오차함수 정의
criterion = nn.BCEWithLogitsLoss(reduction='mean')

# 진짜 img 판정
d_out_real = D(x)

# 가짜 img 생성해 판정
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 오차 계산
d_loss_real = criterion(d_out_real.view(-1), label_real)
d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
d_loss = d_loss_real + d_loss_fake

# %%
'''
G의 오차함수의 이미지 구현
maximize log(D(G(z)))


*** x가 정의되지 않았으므로, 에러가 됩니다
'''

# 가짜 이미지 생성해 판정
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 오차 계산
g_loss = criterion(d_out_fake.view(-1), label_real)

# %% [markdown]
# ## 1-5. DataLoader

# %%
def make_datapath_list():
    """학습 및 검증 화상 데이터와 어노테이션 데이터의 파일 경로 리스트를 작성한다. """

    train_img_list = list() 

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """이미지 전처리 클래스"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """이미지 Dataset 클래스. PyTorch의 Dataset 클래스를 상속"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''이미지 매수를 반환한다'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''전처리한 이미지의 Tensor 형식 데이터 취득'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [높이][폭]흑백

        # 이미지 전처리
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoader 작성과 동작 확인

# 파일 리스트를 작성
train_img_list=make_datapath_list()

# Dataset 작성
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoader 작성
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 동작 확인
batch_iterator = iter(train_dataloader)  # 반복자로 변환
imges = next(batch_iterator)  # 1번째 요소를 꺼낸다
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# ## 1-6. Training

# %%
# 네트워크 초기화
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2d , ConvTranspose2d 초기화
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2d 초기화
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# 초기화 실시
G.apply(weights_init)
D.apply(weights_init)

print("네트워크 초기화 완료")
# Out:
# 네트워크 초기화 완료

# %%
# 모델을 학습시키는 함수를 작성
def train_model(G, D, dataloader, num_epochs):

    # GPU 확인
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("사용 장치: ", device)

    # 최적화 기법 설정
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 오차함수 정의
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # 파라미터 하드코딩
    z_dim = 20
    mini_batch_size = 64

    # 네트워크를 GPU로
    G.to(device)
    D.to(device)

    G.train()  # 모델을 훈련 모드로
    D.train()  # 모델을 훈련 모드로

    # 네트워크가 어느 정도 고정되면, 고속화
    torch.backends.cudnn.benchmark = True

    # 이미지 매수
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # 반복 카운터 설정
    iteration = 1
    logs = []

    # epoch 루프
    for epoch in range(num_epochs):

        # 개시 시간을 저장
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epoch의 손실합
        epoch_d_loss = 0.0  # epoch의 손실합

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('(train)')

        # 데이터 로더에서 minibatch씩 꺼내는 루프
        for imges in dataloader:

            # --------------------
            # 1. Discriminator 학습
            # --------------------
            # 미니 배치 크기가 1이면, 배치 노멀라이제이션에서 에러가 발생하므로 피한다
            if imges.size()[0] == 1:
                continue

            # GPU가 사용 가능하면 GPU로 데이터를 보낸다
            imges = imges.to(device)

            # 정답 라벨과 가짜 라벨 작성
            # epoch의 마지막 반복은 미니 배치 수가 줄어든다
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1.).to(device)   # 1->1.
            label_fake = torch.full((mini_batch_size,), 0.).to(device)   # 0->0.

            # 진짜 이미지 판정
            d_out_real = D(imges)

            # 가짜 이미지 생성해 판정
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 오차를 계산
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generator 학습
            # --------------------
            # 가짜 이미지 생성해 판정
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 오차를 계산
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 기록
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epoch의 phase별 loss와 정답률
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    return G, D

# %%
# 학습 및 검증을 실행
num_epochs = 200
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 사용 장치:  cuda:0
# -------------
# Epoch 0/200
# -------------
# (train)
# -------------
# epoch 0 || Epoch_D_Loss:0.0789 ||Epoch_G_Loss:0.1819
# timer:  143.1013 sec.
# -------------
# Epoch 1/200
# -------------
# (train)
# -------------
# epoch 1 || Epoch_D_Loss:0.0321 ||Epoch_G_Loss:0.3682
# timer:  2.2864 sec.
# -------------
# Epoch 2/200
# -------------
# (train)
# -------------
# epoch 2 || Epoch_D_Loss:0.0216 ||Epoch_G_Loss:0.4234
# timer:  2.2495 sec.
# -------------
# Epoch 3/200
# -------------
# (train)
# -------------
# epoch 3 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.5887
# timer:  2.2672 sec.
# -------------
# Epoch 4/200
# -------------
# (train)
# -------------
# epoch 4 || Epoch_D_Loss:0.1798 ||Epoch_G_Loss:0.2513
# timer:  2.2640 sec.
# -------------
# Epoch 5/200
# -------------
# (train)
# -------------
# epoch 5 || Epoch_D_Loss:0.0950 ||Epoch_G_Loss:0.0759
# timer:  2.2656 sec.
# -------------
# Epoch 6/200
# -------------
# (train)
# -------------
# epoch 6 || Epoch_D_Loss:0.0863 ||Epoch_G_Loss:0.1044
# timer:  2.2718 sec.
# -------------
# Epoch 7/200
# -------------
# (train)
# -------------
# epoch 7 || Epoch_D_Loss:0.0684 ||Epoch_G_Loss:0.1460
# timer:  2.2735 sec.
# -------------
# Epoch 8/200
# -------------
# (train)
# -------------
# epoch 8 || Epoch_D_Loss:0.0155 ||Epoch_G_Loss:0.2686
# timer:  2.2444 sec.
# -------------
# Epoch 9/200
# -------------
# (train)
# -------------
# epoch 9 || Epoch_D_Loss:0.0042 ||Epoch_G_Loss:0.4250
# timer:  2.2626 sec.
# -------------
# Epoch 10/200
# -------------
# (train)
# -------------
# epoch 10 || Epoch_D_Loss:0.0869 ||Epoch_G_Loss:0.4539
# timer:  2.2480 sec.
# -------------
# Epoch 11/200
# -------------
# (train)
# -------------
# epoch 11 || Epoch_D_Loss:0.0726 ||Epoch_G_Loss:0.3347
# timer:  2.2586 sec.
# -------------
# Epoch 12/200
# -------------
# (train)
# -------------
# epoch 12 || Epoch_D_Loss:0.1268 ||Epoch_G_Loss:0.3113
# timer:  2.2859 sec.
# -------------
# Epoch 13/200
# -------------
# (train)
# -------------
# epoch 13 || Epoch_D_Loss:0.0046 ||Epoch_G_Loss:0.4468
# timer:  2.2590 sec.
# -------------
# Epoch 14/200
# -------------
# (train)
# -------------
# epoch 14 || Epoch_D_Loss:0.1839 ||Epoch_G_Loss:0.4064
# timer:  2.2644 sec.
# -------------
# Epoch 15/200
# -------------
# (train)
# -------------
# epoch 15 || Epoch_D_Loss:0.0181 ||Epoch_G_Loss:0.3150
# timer:  2.2484 sec.
# -------------
# Epoch 16/200
# -------------
# (train)
# -------------
# epoch 16 || Epoch_D_Loss:0.0068 ||Epoch_G_Loss:0.4066
# timer:  2.2628 sec.
# -------------
# Epoch 17/200
# -------------
# (train)
# -------------
# epoch 17 || Epoch_D_Loss:0.1722 ||Epoch_G_Loss:0.3216
# timer:  2.2521 sec.
# -------------
# Epoch 18/200
# -------------
# (train)
# -------------
# epoch 18 || Epoch_D_Loss:0.0164 ||Epoch_G_Loss:0.2961
# timer:  2.2475 sec.
# -------------
# Epoch 19/200
# -------------
# (train)
# -------------
# epoch 19 || Epoch_D_Loss:0.1076 ||Epoch_G_Loss:0.3014
# timer:  2.2415 sec.
# -------------
# Epoch 20/200
# -------------
# (train)
# -------------
# epoch 20 || Epoch_D_Loss:0.0123 ||Epoch_G_Loss:0.3061
# timer:  2.2560 sec.
# -------------
# Epoch 21/200
# -------------
# (train)
# -------------
# epoch 21 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.4141
# timer:  2.2378 sec.
# -------------
# Epoch 22/200
# -------------
# (train)
# -------------
# epoch 22 || Epoch_D_Loss:0.2206 ||Epoch_G_Loss:0.4047
# timer:  2.2392 sec.
# -------------
# Epoch 23/200
# -------------
# (train)
# -------------
# epoch 23 || Epoch_D_Loss:0.0945 ||Epoch_G_Loss:0.2105
# timer:  2.2444 sec.
# -------------
# Epoch 24/200
# -------------
# (train)
# -------------
# epoch 24 || Epoch_D_Loss:0.0649 ||Epoch_G_Loss:0.2601
# timer:  2.2324 sec.
# -------------
# Epoch 25/200
# -------------
# (train)
# -------------
# epoch 25 || Epoch_D_Loss:0.0859 ||Epoch_G_Loss:0.2689
# timer:  2.2736 sec.
# -------------
# Epoch 26/200
# -------------
# (train)
# -------------
# epoch 26 || Epoch_D_Loss:0.1427 ||Epoch_G_Loss:0.2237
# timer:  2.2535 sec.
# -------------
# Epoch 27/200
# -------------
# (train)
# -------------
# epoch 27 || Epoch_D_Loss:0.0280 ||Epoch_G_Loss:0.2304
# timer:  2.2600 sec.
# -------------
# Epoch 28/200
# -------------
# (train)
# -------------
# epoch 28 || Epoch_D_Loss:0.1558 ||Epoch_G_Loss:0.2299
# timer:  2.2484 sec.
# -------------
# Epoch 29/200
# -------------
# (train)
# -------------
# epoch 29 || Epoch_D_Loss:0.1119 ||Epoch_G_Loss:0.1970
# timer:  2.2452 sec.
# -------------
# Epoch 30/200
# -------------
# (train)
# -------------
# epoch 30 || Epoch_D_Loss:0.1014 ||Epoch_G_Loss:0.1729
# timer:  2.2730 sec.
# -------------
# Epoch 31/200
# -------------
# (train)
# -------------
# epoch 31 || Epoch_D_Loss:0.0919 ||Epoch_G_Loss:0.1494
# timer:  2.2321 sec.
# -------------
# Epoch 32/200
# -------------
# (train)
# -------------
# epoch 32 || Epoch_D_Loss:0.1029 ||Epoch_G_Loss:0.1604
# timer:  2.2655 sec.
# -------------
# Epoch 33/200
# -------------
# (train)
# -------------
# epoch 33 || Epoch_D_Loss:0.0915 ||Epoch_G_Loss:0.2070
# timer:  2.2255 sec.
# -------------
# Epoch 34/200
# -------------
# (train)
# -------------
# epoch 34 || Epoch_D_Loss:0.1315 ||Epoch_G_Loss:0.1446
# timer:  2.2480 sec.
# -------------
# Epoch 35/200
# -------------
# (train)
# -------------
# epoch 35 || Epoch_D_Loss:0.0982 ||Epoch_G_Loss:0.1560
# timer:  2.2803 sec.
# -------------
# Epoch 36/200
# -------------
# (train)
# -------------
# epoch 36 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.1559
# timer:  2.2447 sec.
# -------------
# Epoch 37/200
# -------------
# (train)
# -------------
# epoch 37 || Epoch_D_Loss:0.1015 ||Epoch_G_Loss:0.1535
# timer:  2.2554 sec.
# -------------
# Epoch 38/200
# -------------
# (train)
# -------------
# epoch 38 || Epoch_D_Loss:0.1088 ||Epoch_G_Loss:0.1603
# timer:  2.2427 sec.
# -------------
# Epoch 39/200
# -------------
# (train)
# -------------
# epoch 39 || Epoch_D_Loss:0.1036 ||Epoch_G_Loss:0.1587
# timer:  2.2564 sec.
# -------------
# Epoch 40/200
# -------------
# (train)
# -------------
# epoch 40 || Epoch_D_Loss:0.1306 ||Epoch_G_Loss:0.1501
# timer:  2.2287 sec.
# -------------
# Epoch 41/200
# -------------
# (train)
# -------------
# epoch 41 || Epoch_D_Loss:0.1138 ||Epoch_G_Loss:0.1542
# timer:  2.2639 sec.
# -------------
# Epoch 42/200
# -------------
# (train)
# -------------
# epoch 42 || Epoch_D_Loss:0.1206 ||Epoch_G_Loss:0.1130
# timer:  2.2499 sec.
# -------------
# Epoch 43/200
# -------------
# (train)
# -------------
# epoch 43 || Epoch_D_Loss:0.1317 ||Epoch_G_Loss:0.1282
# timer:  2.2760 sec.
# -------------
# Epoch 44/200
# -------------
# (train)
# -------------
# epoch 44 || Epoch_D_Loss:0.1432 ||Epoch_G_Loss:0.1276
# timer:  2.2467 sec.
# -------------
# Epoch 45/200
# -------------
# (train)
# -------------
# epoch 45 || Epoch_D_Loss:0.1301 ||Epoch_G_Loss:0.1011
# timer:  2.2470 sec.
# -------------
# Epoch 46/200
# -------------
# (train)
# -------------
# epoch 46 || Epoch_D_Loss:0.1268 ||Epoch_G_Loss:0.1188
# timer:  2.2824 sec.
# -------------
# Epoch 47/200
# -------------
# (train)
# -------------
# epoch 47 || Epoch_D_Loss:0.1301 ||Epoch_G_Loss:0.1310
# timer:  2.2478 sec.
# -------------
# Epoch 48/200
# -------------
# (train)
# -------------
# epoch 48 || Epoch_D_Loss:0.1066 ||Epoch_G_Loss:0.1377
# timer:  2.2900 sec.
# -------------
# Epoch 49/200
# -------------
# (train)
# -------------
# epoch 49 || Epoch_D_Loss:0.1261 ||Epoch_G_Loss:0.1122
# timer:  2.2704 sec.
# -------------
# Epoch 50/200
# -------------
# (train)
# -------------
# epoch 50 || Epoch_D_Loss:0.1192 ||Epoch_G_Loss:0.1222
# timer:  2.2594 sec.
# -------------
# Epoch 51/200
# -------------
# (train)
# -------------
# epoch 51 || Epoch_D_Loss:0.1387 ||Epoch_G_Loss:0.1217
# timer:  2.2763 sec.
# -------------
# Epoch 52/200
# -------------
# (train)
# -------------
# epoch 52 || Epoch_D_Loss:0.1274 ||Epoch_G_Loss:0.1224
# timer:  2.2503 sec.
# -------------
# Epoch 53/200
# -------------
# (train)
# -------------
# epoch 53 || Epoch_D_Loss:0.1115 ||Epoch_G_Loss:0.1184
# timer:  2.2453 sec.
# -------------
# Epoch 54/200
# -------------
# (train)
# -------------
# epoch 54 || Epoch_D_Loss:0.1305 ||Epoch_G_Loss:0.1230
# timer:  2.2503 sec.
# -------------
# Epoch 55/200
# -------------
# (train)
# -------------
# epoch 55 || Epoch_D_Loss:0.1135 ||Epoch_G_Loss:0.1416
# timer:  2.2363 sec.
# -------------
# Epoch 56/200
# -------------
# (train)
# -------------
# epoch 56 || Epoch_D_Loss:0.1140 ||Epoch_G_Loss:0.1337
# timer:  2.2414 sec.
# -------------
# Epoch 57/200
# -------------
# (train)
# -------------
# epoch 57 || Epoch_D_Loss:0.1182 ||Epoch_G_Loss:0.1472
# timer:  2.2352 sec.
# -------------
# Epoch 58/200
# -------------
# (train)
# -------------
# epoch 58 || Epoch_D_Loss:0.1057 ||Epoch_G_Loss:0.1194
# timer:  2.2676 sec.
# -------------
# Epoch 59/200
# -------------
# (train)
# -------------
# epoch 59 || Epoch_D_Loss:0.1142 ||Epoch_G_Loss:0.1422
# timer:  2.2511 sec.
# -------------
# Epoch 60/200
# -------------
# (train)
# -------------
# epoch 60 || Epoch_D_Loss:0.1046 ||Epoch_G_Loss:0.1316
# timer:  2.2216 sec.
# -------------
# Epoch 61/200
# -------------
# (train)
# -------------
# epoch 61 || Epoch_D_Loss:0.1006 ||Epoch_G_Loss:0.1546
# timer:  2.2652 sec.
# -------------
# Epoch 62/200
# -------------
# (train)
# -------------
# epoch 62 || Epoch_D_Loss:0.1047 ||Epoch_G_Loss:0.1378
# timer:  2.2244 sec.
# -------------
# Epoch 63/200
# -------------
# (train)
# -------------
# epoch 63 || Epoch_D_Loss:0.1019 ||Epoch_G_Loss:0.1589
# timer:  2.2428 sec.
# -------------
# Epoch 64/200
# -------------
# (train)
# -------------
# epoch 64 || Epoch_D_Loss:0.0887 ||Epoch_G_Loss:0.1535
# timer:  2.2678 sec.
# -------------
# Epoch 65/200
# -------------
# (train)
# -------------
# epoch 65 || Epoch_D_Loss:0.1122 ||Epoch_G_Loss:0.1662
# timer:  2.2425 sec.
# -------------
# Epoch 66/200
# -------------
# (train)
# -------------
# epoch 66 || Epoch_D_Loss:0.0995 ||Epoch_G_Loss:0.1455
# timer:  2.2504 sec.
# -------------
# Epoch 67/200
# -------------
# (train)
# -------------
# epoch 67 || Epoch_D_Loss:0.0990 ||Epoch_G_Loss:0.1657
# timer:  2.2723 sec.
# -------------
# Epoch 68/200
# -------------
# (train)
# -------------
# epoch 68 || Epoch_D_Loss:0.0963 ||Epoch_G_Loss:0.1504
# timer:  2.2735 sec.
# -------------
# Epoch 69/200
# -------------
# (train)
# -------------
# epoch 69 || Epoch_D_Loss:0.1006 ||Epoch_G_Loss:0.1665
# timer:  2.2372 sec.
# -------------
# Epoch 70/200
# -------------
# (train)
# -------------
# epoch 70 || Epoch_D_Loss:0.1088 ||Epoch_G_Loss:0.1695
# timer:  2.2639 sec.
# -------------
# Epoch 71/200
# -------------
# (train)
# -------------
# epoch 71 || Epoch_D_Loss:0.0822 ||Epoch_G_Loss:0.1544
# timer:  2.2145 sec.
# -------------
# Epoch 72/200
# -------------
# (train)
# -------------
# epoch 72 || Epoch_D_Loss:0.1044 ||Epoch_G_Loss:0.1740
# timer:  2.2734 sec.
# -------------
# Epoch 73/200
# -------------
# (train)
# -------------
# epoch 73 || Epoch_D_Loss:0.0949 ||Epoch_G_Loss:0.1801
# timer:  2.2409 sec.
# -------------
# Epoch 74/200
# -------------
# (train)
# -------------
# epoch 74 || Epoch_D_Loss:0.0951 ||Epoch_G_Loss:0.1501
# timer:  2.2337 sec.
# -------------
# Epoch 75/200
# -------------
# (train)
# -------------
# epoch 75 || Epoch_D_Loss:0.0901 ||Epoch_G_Loss:0.1816
# timer:  2.2719 sec.
# -------------
# Epoch 76/200
# -------------
# (train)
# -------------
# epoch 76 || Epoch_D_Loss:0.1007 ||Epoch_G_Loss:0.1582
# timer:  2.2503 sec.
# -------------
# Epoch 77/200
# -------------
# (train)
# -------------
# epoch 77 || Epoch_D_Loss:0.0854 ||Epoch_G_Loss:0.1908
# timer:  2.2623 sec.
# -------------
# Epoch 78/200
# -------------
# (train)
# -------------
# epoch 78 || Epoch_D_Loss:0.0988 ||Epoch_G_Loss:0.1493
# timer:  2.2296 sec.
# -------------
# Epoch 79/200
# -------------
# (train)
# -------------
# epoch 79 || Epoch_D_Loss:0.1080 ||Epoch_G_Loss:0.1810
# timer:  2.2513 sec.
# -------------
# Epoch 80/200
# -------------
# (train)
# -------------
# epoch 80 || Epoch_D_Loss:0.0889 ||Epoch_G_Loss:0.1590
# timer:  2.2564 sec.
# -------------
# Epoch 81/200
# -------------
# (train)
# -------------
# epoch 81 || Epoch_D_Loss:0.0946 ||Epoch_G_Loss:0.1734
# timer:  2.2337 sec.
# -------------
# Epoch 82/200
# -------------
# (train)
# -------------
# epoch 82 || Epoch_D_Loss:0.0970 ||Epoch_G_Loss:0.1611
# timer:  2.2546 sec.
# -------------
# Epoch 83/200
# -------------
# (train)
# -------------
# epoch 83 || Epoch_D_Loss:0.0706 ||Epoch_G_Loss:0.1676
# timer:  2.2610 sec.
# -------------
# Epoch 84/200
# -------------
# (train)
# -------------
# epoch 84 || Epoch_D_Loss:0.1221 ||Epoch_G_Loss:0.1883
# timer:  2.2557 sec.
# -------------
# Epoch 85/200
# -------------
# (train)
# -------------
# epoch 85 || Epoch_D_Loss:0.0784 ||Epoch_G_Loss:0.1668
# timer:  2.2478 sec.
# -------------
# Epoch 86/200
# -------------
# (train)
# -------------
# epoch 86 || Epoch_D_Loss:0.0954 ||Epoch_G_Loss:0.1812
# timer:  2.2094 sec.
# -------------
# Epoch 87/200
# -------------
# (train)
# -------------
# epoch 87 || Epoch_D_Loss:0.0922 ||Epoch_G_Loss:0.1662
# timer:  2.2597 sec.
# -------------
# Epoch 88/200
# -------------
# (train)
# -------------
# epoch 88 || Epoch_D_Loss:0.0947 ||Epoch_G_Loss:0.1751
# timer:  2.2677 sec.
# -------------
# Epoch 89/200
# -------------
# (train)
# -------------
# epoch 89 || Epoch_D_Loss:0.0757 ||Epoch_G_Loss:0.1686
# timer:  2.2545 sec.
# -------------
# Epoch 90/200
# -------------
# (train)
# -------------
# epoch 90 || Epoch_D_Loss:0.1038 ||Epoch_G_Loss:0.1949
# timer:  2.2287 sec.
# -------------
# Epoch 91/200
# -------------
# (train)
# -------------
# epoch 91 || Epoch_D_Loss:0.1003 ||Epoch_G_Loss:0.1768
# timer:  2.2265 sec.
# -------------
# Epoch 92/200
# -------------
# (train)
# -------------
# epoch 92 || Epoch_D_Loss:0.0752 ||Epoch_G_Loss:0.1891
# timer:  2.2637 sec.
# -------------
# Epoch 93/200
# -------------
# (train)
# -------------
# epoch 93 || Epoch_D_Loss:0.0997 ||Epoch_G_Loss:0.1680
# timer:  2.2374 sec.
# -------------
# Epoch 94/200
# -------------
# (train)
# -------------
# epoch 94 || Epoch_D_Loss:0.0812 ||Epoch_G_Loss:0.1844
# timer:  2.2269 sec.
# -------------
# Epoch 95/200
# -------------
# (train)
# -------------
# epoch 95 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1761
# timer:  2.2712 sec.
# -------------
# Epoch 96/200
# -------------
# (train)
# -------------
# epoch 96 || Epoch_D_Loss:0.0786 ||Epoch_G_Loss:0.1823
# timer:  2.2346 sec.
# -------------
# Epoch 97/200
# -------------
# (train)
# -------------
# epoch 97 || Epoch_D_Loss:0.0888 ||Epoch_G_Loss:0.1797
# timer:  2.2618 sec.
# -------------
# Epoch 98/200
# -------------
# (train)
# -------------
# epoch 98 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.1869
# timer:  2.2253 sec.
# -------------
# Epoch 99/200
# -------------
# (train)
# -------------
# epoch 99 || Epoch_D_Loss:0.0814 ||Epoch_G_Loss:0.1874
# timer:  2.2628 sec.
# -------------
# Epoch 100/200
# -------------
# (train)
# -------------
# epoch 100 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1986
# timer:  2.2722 sec.
# -------------
# Epoch 101/200
# -------------
# (train)
# -------------
# epoch 101 || Epoch_D_Loss:0.0873 ||Epoch_G_Loss:0.1858
# timer:  2.2342 sec.
# -------------
# Epoch 102/200
# -------------
# (train)
# -------------
# epoch 102 || Epoch_D_Loss:0.0772 ||Epoch_G_Loss:0.1926
# timer:  2.2411 sec.
# -------------
# Epoch 103/200
# -------------
# (train)
# -------------
# epoch 103 || Epoch_D_Loss:0.0951 ||Epoch_G_Loss:0.1787
# timer:  2.2689 sec.
# -------------
# Epoch 104/200
# -------------
# (train)
# -------------
# epoch 104 || Epoch_D_Loss:0.0865 ||Epoch_G_Loss:0.1898
# timer:  2.2831 sec.
# -------------
# Epoch 105/200
# -------------
# (train)
# -------------
# epoch 105 || Epoch_D_Loss:0.0831 ||Epoch_G_Loss:0.1733
# timer:  2.2638 sec.
# -------------
# Epoch 106/200
# -------------
# (train)
# -------------
# epoch 106 || Epoch_D_Loss:0.0746 ||Epoch_G_Loss:0.2152
# timer:  2.2408 sec.
# -------------
# Epoch 107/200
# -------------
# (train)
# -------------
# epoch 107 || Epoch_D_Loss:0.1066 ||Epoch_G_Loss:0.1944
# timer:  2.2403 sec.
# -------------
# Epoch 108/200
# -------------
# (train)
# -------------
# epoch 108 || Epoch_D_Loss:0.0677 ||Epoch_G_Loss:0.2076
# timer:  2.2617 sec.
# -------------
# Epoch 109/200
# -------------
# (train)
# -------------
# epoch 109 || Epoch_D_Loss:0.0857 ||Epoch_G_Loss:0.1893
# timer:  2.2662 sec.
# -------------
# Epoch 110/200
# -------------
# (train)
# -------------
# epoch 110 || Epoch_D_Loss:0.0827 ||Epoch_G_Loss:0.2130
# timer:  2.2548 sec.
# -------------
# Epoch 111/200
# -------------
# (train)
# -------------
# epoch 111 || Epoch_D_Loss:0.0668 ||Epoch_G_Loss:0.2048
# timer:  2.2661 sec.
# -------------
# Epoch 112/200
# -------------
# (train)
# -------------
# epoch 112 || Epoch_D_Loss:0.0979 ||Epoch_G_Loss:0.2174
# timer:  2.2548 sec.
# -------------
# Epoch 113/200
# -------------
# (train)
# -------------
# epoch 113 || Epoch_D_Loss:0.0615 ||Epoch_G_Loss:0.1948
# timer:  2.2579 sec.
# -------------
# Epoch 114/200
# -------------
# (train)
# -------------
# epoch 114 || Epoch_D_Loss:0.0982 ||Epoch_G_Loss:0.2040
# timer:  2.2541 sec.
# -------------
# Epoch 115/200
# -------------
# (train)
# -------------
# epoch 115 || Epoch_D_Loss:0.0612 ||Epoch_G_Loss:0.2032
# timer:  2.2271 sec.
# -------------
# Epoch 116/200
# -------------
# (train)
# -------------
# epoch 116 || Epoch_D_Loss:0.0938 ||Epoch_G_Loss:0.2021
# timer:  2.2496 sec.
# -------------
# Epoch 117/200
# -------------
# (train)
# -------------
# epoch 117 || Epoch_D_Loss:0.0606 ||Epoch_G_Loss:0.2289
# timer:  2.2568 sec.
# -------------
# Epoch 118/200
# -------------
# (train)
# -------------
# epoch 118 || Epoch_D_Loss:0.0929 ||Epoch_G_Loss:0.1973
# timer:  2.2493 sec.
# -------------
# Epoch 119/200
# -------------
# (train)
# -------------
# epoch 119 || Epoch_D_Loss:0.0650 ||Epoch_G_Loss:0.2185
# timer:  2.2696 sec.
# -------------
# Epoch 120/200
# -------------
# (train)
# -------------
# epoch 120 || Epoch_D_Loss:0.0910 ||Epoch_G_Loss:0.2241
# timer:  2.2504 sec.
# -------------
# Epoch 121/200
# -------------
# (train)
# -------------
# epoch 121 || Epoch_D_Loss:0.0528 ||Epoch_G_Loss:0.2222
# timer:  2.2593 sec.
# -------------
# Epoch 122/200
# -------------
# (train)
# -------------
# epoch 122 || Epoch_D_Loss:0.1111 ||Epoch_G_Loss:0.2295
# timer:  2.2322 sec.
# -------------
# Epoch 123/200
# -------------
# (train)
# -------------
# epoch 123 || Epoch_D_Loss:0.0501 ||Epoch_G_Loss:0.2191
# timer:  2.2216 sec.
# -------------
# Epoch 124/200
# -------------
# (train)
# -------------
# epoch 124 || Epoch_D_Loss:0.0978 ||Epoch_G_Loss:0.2333
# timer:  2.2735 sec.
# -------------
# Epoch 125/200
# -------------
# (train)
# -------------
# epoch 125 || Epoch_D_Loss:0.0510 ||Epoch_G_Loss:0.2362
# timer:  2.2519 sec.
# -------------
# Epoch 126/200
# -------------
# (train)
# -------------
# epoch 126 || Epoch_D_Loss:0.0962 ||Epoch_G_Loss:0.2400
# timer:  2.2904 sec.
# -------------
# Epoch 127/200
# -------------
# (train)
# -------------
# epoch 127 || Epoch_D_Loss:0.0563 ||Epoch_G_Loss:0.2262
# timer:  2.2344 sec.
# -------------
# Epoch 128/200
# -------------
# (train)
# -------------
# epoch 128 || Epoch_D_Loss:0.0804 ||Epoch_G_Loss:0.2292
# timer:  2.2453 sec.
# -------------
# Epoch 129/200
# -------------
# (train)
# -------------
# epoch 129 || Epoch_D_Loss:0.0510 ||Epoch_G_Loss:0.2404
# timer:  2.2578 sec.
# -------------
# Epoch 130/200
# -------------
# (train)
# -------------
# epoch 130 || Epoch_D_Loss:0.0873 ||Epoch_G_Loss:0.2486
# timer:  2.2336 sec.
# -------------
# Epoch 131/200
# -------------
# (train)
# -------------
# epoch 131 || Epoch_D_Loss:0.0599 ||Epoch_G_Loss:0.2174
# timer:  2.2586 sec.
# -------------
# Epoch 132/200
# -------------
# (train)
# -------------
# epoch 132 || Epoch_D_Loss:0.0693 ||Epoch_G_Loss:0.2376
# timer:  2.2377 sec.
# -------------
# Epoch 133/200
# -------------
# (train)
# -------------
# epoch 133 || Epoch_D_Loss:0.0761 ||Epoch_G_Loss:0.2226
# timer:  2.2632 sec.
# -------------
# Epoch 134/200
# -------------
# (train)
# -------------
# epoch 134 || Epoch_D_Loss:0.0665 ||Epoch_G_Loss:0.2277
# timer:  2.2654 sec.
# -------------
# Epoch 135/200
# -------------
# (train)
# -------------
# epoch 135 || Epoch_D_Loss:0.0622 ||Epoch_G_Loss:0.2740
# timer:  2.2724 sec.
# -------------
# Epoch 136/200
# -------------
# (train)
# -------------
# epoch 136 || Epoch_D_Loss:0.0715 ||Epoch_G_Loss:0.2582
# timer:  2.2273 sec.
# -------------
# Epoch 137/200
# -------------
# (train)
# -------------
# epoch 137 || Epoch_D_Loss:0.0755 ||Epoch_G_Loss:0.2539
# timer:  2.2677 sec.
# -------------
# Epoch 138/200
# -------------
# (train)
# -------------
# epoch 138 || Epoch_D_Loss:0.0593 ||Epoch_G_Loss:0.2502
# timer:  2.2252 sec.
# -------------
# Epoch 139/200
# -------------
# (train)
# -------------
# epoch 139 || Epoch_D_Loss:0.0761 ||Epoch_G_Loss:0.2579
# timer:  2.2249 sec.
# -------------
# Epoch 140/200
# -------------
# (train)
# -------------
# epoch 140 || Epoch_D_Loss:0.0492 ||Epoch_G_Loss:0.2351
# timer:  2.2611 sec.
# -------------
# Epoch 141/200
# -------------
# (train)
# -------------
# epoch 141 || Epoch_D_Loss:0.0717 ||Epoch_G_Loss:0.2696
# timer:  2.2663 sec.
# -------------
# Epoch 142/200
# -------------
# (train)
# -------------
# epoch 142 || Epoch_D_Loss:0.0665 ||Epoch_G_Loss:0.2412
# timer:  2.2595 sec.
# -------------
# Epoch 143/200
# -------------
# (train)
# -------------
# epoch 143 || Epoch_D_Loss:0.0539 ||Epoch_G_Loss:0.2612
# timer:  2.2166 sec.
# -------------
# Epoch 144/200
# -------------
# (train)
# -------------
# epoch 144 || Epoch_D_Loss:0.0587 ||Epoch_G_Loss:0.3022
# timer:  2.2343 sec.
# -------------
# Epoch 145/200
# -------------
# (train)
# -------------
# epoch 145 || Epoch_D_Loss:0.0585 ||Epoch_G_Loss:0.2454
# timer:  2.2635 sec.
# -------------
# Epoch 146/200
# -------------
# (train)
# -------------
# epoch 146 || Epoch_D_Loss:0.0605 ||Epoch_G_Loss:0.2927
# timer:  2.2206 sec.
# -------------
# Epoch 147/200
# -------------
# (train)
# -------------
# epoch 147 || Epoch_D_Loss:0.0493 ||Epoch_G_Loss:0.2622
# timer:  2.2650 sec.
# -------------
# Epoch 148/200
# -------------
# (train)
# -------------
# epoch 148 || Epoch_D_Loss:0.0655 ||Epoch_G_Loss:0.2961
# timer:  2.2412 sec.
# -------------
# Epoch 149/200
# -------------
# (train)
# -------------
# epoch 149 || Epoch_D_Loss:0.0563 ||Epoch_G_Loss:0.2514
# timer:  2.2619 sec.
# -------------
# Epoch 150/200
# -------------
# (train)
# -------------
# epoch 150 || Epoch_D_Loss:0.0461 ||Epoch_G_Loss:0.2754
# timer:  2.2540 sec.
# -------------
# Epoch 151/200
# -------------
# (train)
# -------------
# epoch 151 || Epoch_D_Loss:0.0719 ||Epoch_G_Loss:0.2741
# timer:  2.2728 sec.
# -------------
# Epoch 152/200
# -------------
# (train)
# -------------
# epoch 152 || Epoch_D_Loss:0.0686 ||Epoch_G_Loss:0.3085
# timer:  2.2556 sec.
# -------------
# Epoch 153/200
# -------------
# (train)
# -------------
# epoch 153 || Epoch_D_Loss:0.0593 ||Epoch_G_Loss:0.2471
# timer:  2.2280 sec.
# -------------
# Epoch 154/200
# -------------
# (train)
# -------------
# epoch 154 || Epoch_D_Loss:0.0498 ||Epoch_G_Loss:0.3027
# timer:  2.2451 sec.
# -------------
# Epoch 155/200
# -------------
# (train)
# -------------
# epoch 155 || Epoch_D_Loss:0.0452 ||Epoch_G_Loss:0.2863
# timer:  2.2283 sec.
# -------------
# Epoch 156/200
# -------------
# (train)
# -------------
# epoch 156 || Epoch_D_Loss:0.0722 ||Epoch_G_Loss:0.2938
# timer:  2.2478 sec.
# -------------
# Epoch 157/200
# -------------
# (train)
# -------------
# epoch 157 || Epoch_D_Loss:0.0283 ||Epoch_G_Loss:0.3330
# timer:  2.2672 sec.
# -------------
# Epoch 158/200
# -------------
# (train)
# -------------
# epoch 158 || Epoch_D_Loss:0.0917 ||Epoch_G_Loss:0.2635
# timer:  2.2495 sec.
# -------------
# Epoch 159/200
# -------------
# (train)
# -------------
# epoch 159 || Epoch_D_Loss:0.0306 ||Epoch_G_Loss:0.2956
# timer:  2.2482 sec.
# -------------
# Epoch 160/200
# -------------
# (train)
# -------------
# epoch 160 || Epoch_D_Loss:0.0722 ||Epoch_G_Loss:0.3088
# timer:  2.2492 sec.
# -------------
# Epoch 161/200
# -------------
# (train)
# -------------
# epoch 161 || Epoch_D_Loss:0.0373 ||Epoch_G_Loss:0.2997
# timer:  2.2413 sec.
# -------------
# Epoch 162/200
# -------------
# (train)
# -------------
# epoch 162 || Epoch_D_Loss:0.0753 ||Epoch_G_Loss:0.3272
# timer:  2.2331 sec.
# -------------
# Epoch 163/200
# -------------
# (train)
# -------------
# epoch 163 || Epoch_D_Loss:0.0409 ||Epoch_G_Loss:0.2799
# timer:  2.2394 sec.
# -------------
# Epoch 164/200
# -------------
# (train)
# -------------
# epoch 164 || Epoch_D_Loss:0.0544 ||Epoch_G_Loss:0.3121
# timer:  2.2777 sec.
# -------------
# Epoch 165/200
# -------------
# (train)
# -------------
# epoch 165 || Epoch_D_Loss:0.0357 ||Epoch_G_Loss:0.3240
# timer:  2.2729 sec.
# -------------
# Epoch 166/200
# -------------
# (train)
# -------------
# epoch 166 || Epoch_D_Loss:0.0822 ||Epoch_G_Loss:0.3323
# timer:  2.2589 sec.
# -------------
# Epoch 167/200
# -------------
# (train)
# -------------
# epoch 167 || Epoch_D_Loss:0.0384 ||Epoch_G_Loss:0.2931
# timer:  2.2533 sec.
# -------------
# Epoch 168/200
# -------------
# (train)
# -------------
# epoch 168 || Epoch_D_Loss:0.0424 ||Epoch_G_Loss:0.3166
# timer:  2.2681 sec.
# -------------
# Epoch 169/200
# -------------
# (train)
# -------------
# epoch 169 || Epoch_D_Loss:0.0523 ||Epoch_G_Loss:0.3128
# timer:  2.2334 sec.
# -------------
# Epoch 170/200
# -------------
# (train)
# -------------
# epoch 170 || Epoch_D_Loss:0.0427 ||Epoch_G_Loss:0.3232
# timer:  2.2475 sec.
# -------------
# Epoch 171/200
# -------------
# (train)
# -------------
# epoch 171 || Epoch_D_Loss:0.0680 ||Epoch_G_Loss:0.3193
# timer:  2.2423 sec.
# -------------
# Epoch 172/200
# -------------
# (train)
# -------------
# epoch 172 || Epoch_D_Loss:0.0353 ||Epoch_G_Loss:0.3135
# timer:  2.2426 sec.
# -------------
# Epoch 173/200
# -------------
# (train)
# -------------
# epoch 173 || Epoch_D_Loss:0.0489 ||Epoch_G_Loss:0.3348
# timer:  2.2637 sec.
# -------------
# Epoch 174/200
# -------------
# (train)
# -------------
# epoch 174 || Epoch_D_Loss:0.0333 ||Epoch_G_Loss:0.2976
# timer:  2.2198 sec.
# -------------
# Epoch 175/200
# -------------
# (train)
# -------------
# epoch 175 || Epoch_D_Loss:0.0709 ||Epoch_G_Loss:0.3171
# timer:  2.2799 sec.
# -------------
# Epoch 176/200
# -------------
# (train)
# -------------
# epoch 176 || Epoch_D_Loss:0.0287 ||Epoch_G_Loss:0.3486
# timer:  2.2379 sec.
# -------------
# Epoch 177/200
# -------------
# (train)
# -------------
# epoch 177 || Epoch_D_Loss:0.0831 ||Epoch_G_Loss:0.3020
# timer:  2.2688 sec.
# -------------
# Epoch 178/200
# -------------
# (train)
# -------------
# epoch 178 || Epoch_D_Loss:0.0252 ||Epoch_G_Loss:0.3304
# timer:  2.2506 sec.
# -------------
# Epoch 179/200
# -------------
# (train)
# -------------
# epoch 179 || Epoch_D_Loss:0.0633 ||Epoch_G_Loss:0.2997
# timer:  2.2783 sec.
# -------------
# Epoch 180/200
# -------------
# (train)
# -------------
# epoch 180 || Epoch_D_Loss:0.0239 ||Epoch_G_Loss:0.3521
# timer:  2.2460 sec.
# -------------
# Epoch 181/200
# -------------
# (train)
# -------------
# epoch 181 || Epoch_D_Loss:0.0626 ||Epoch_G_Loss:0.3863
# timer:  2.2331 sec.
# -------------
# Epoch 182/200
# -------------
# (train)
# -------------
# epoch 182 || Epoch_D_Loss:0.0515 ||Epoch_G_Loss:0.2979
# timer:  2.2590 sec.
# -------------
# Epoch 183/200
# -------------
# (train)
# -------------
# epoch 183 || Epoch_D_Loss:0.0275 ||Epoch_G_Loss:0.3457
# timer:  2.2708 sec.
# -------------
# Epoch 184/200
# -------------
# (train)
# -------------
# epoch 184 || Epoch_D_Loss:0.0500 ||Epoch_G_Loss:0.3632
# timer:  2.2725 sec.
# -------------
# Epoch 185/200
# -------------
# (train)
# -------------
# epoch 185 || Epoch_D_Loss:0.0378 ||Epoch_G_Loss:0.3284
# timer:  2.2553 sec.
# -------------
# Epoch 186/200
# -------------
# (train)
# -------------
# epoch 186 || Epoch_D_Loss:0.0341 ||Epoch_G_Loss:0.3910
# timer:  2.3123 sec.
# -------------
# Epoch 187/200
# -------------
# (train)
# -------------
# epoch 187 || Epoch_D_Loss:0.0576 ||Epoch_G_Loss:0.3322
# timer:  2.2881 sec.
# -------------
# Epoch 188/200
# -------------
# (train)
# -------------
# epoch 188 || Epoch_D_Loss:0.0196 ||Epoch_G_Loss:0.3673
# timer:  2.2640 sec.
# -------------
# Epoch 189/200
# -------------
# (train)
# -------------
# epoch 189 || Epoch_D_Loss:0.0889 ||Epoch_G_Loss:0.3466
# timer:  2.2743 sec.
# -------------
# Epoch 190/200
# -------------
# (train)
# -------------
# epoch 190 || Epoch_D_Loss:0.0207 ||Epoch_G_Loss:0.3487
# timer:  2.2659 sec.
# -------------
# Epoch 191/200
# -------------
# (train)
# -------------
# epoch 191 || Epoch_D_Loss:0.0153 ||Epoch_G_Loss:0.3589
# timer:  2.2524 sec.
# -------------
# Epoch 192/200
# -------------
# (train)
# -------------
# epoch 192 || Epoch_D_Loss:0.0933 ||Epoch_G_Loss:0.4140
# timer:  2.2662 sec.
# -------------
# Epoch 193/200
# -------------
# (train)
# -------------
# epoch 193 || Epoch_D_Loss:0.0195 ||Epoch_G_Loss:0.3580
# timer:  2.2458 sec.
# -------------
# Epoch 194/200
# -------------
# (train)
# -------------
# epoch 194 || Epoch_D_Loss:0.0182 ||Epoch_G_Loss:0.3901
# timer:  2.2326 sec.
# -------------
# Epoch 195/200
# -------------
# (train)
# -------------
# epoch 195 || Epoch_D_Loss:0.1050 ||Epoch_G_Loss:0.4195
# timer:  2.2463 sec.
# -------------
# Epoch 196/200
# -------------
# (train)
# -------------
# epoch 196 || Epoch_D_Loss:0.0290 ||Epoch_G_Loss:0.3553
# timer:  2.2559 sec.
# -------------
# Epoch 197/200
# -------------
# (train)
# -------------
# epoch 197 || Epoch_D_Loss:0.0346 ||Epoch_G_Loss:0.3690
# timer:  2.2584 sec.
# -------------
# Epoch 198/200
# -------------
# (train)
# -------------
# epoch 198 || Epoch_D_Loss:0.0318 ||Epoch_G_Loss:0.3863
# timer:  2.2484 sec.
# -------------
# Epoch 199/200
# -------------
# (train)
# -------------
# epoch 199 || Epoch_D_Loss:0.0244 ||Epoch_G_Loss:0.4122
# timer:  2.2669 sec.

# %%
# 생성 화상과 훈련 데이터를 시각화

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 입력 난수 생성
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 화상 생성
G_update.eval()
fake_images = G_update(fixed_z.to(device))

# 훈련 데이터
batch_iterator = iter(train_dataloader)  # 반복자로 변환
imges = next(batch_iterator)  # 1번째 요소를 꺼낸다


# 출력
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 상단에 훈련 데이터를,
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 하단에 생성 데이터를 표시한다
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# # 2.SAGAN

# %%
# 패키지 import
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# ## 2-1. Self-Attention Module

# %%
class Self_Attention(nn.Module):
    """Self-Attention의 Layer"""

    def __init__(self, in_dim):
        super(Self_Attention, self).__init__()

        # 1×1의 합성곱 층에 의한 pointwise convolution를 준비
        self.query_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.key_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.value_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim, kernel_size=1)

        # Attention Map 작성시 규격화 소프트맥스
        self.softmax = nn.Softmax(dim=-2)

        # 원래 입력 x와 Self-Attention Map인 o를 더할 때의 계수
        # output = x + gamma*o
        # 처음에는 gamma=0으로 학습시킨다
        self.gamma = nn.Parameter(torch.zeros(1))

    def forward(self, x):

        # 입력 변수
        X = x

        # 합성곱한 뒤, 크기를 변형시킨다.  
        # B, C', W, H -> B, C', N 으로
        proj_query = self.query_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # 크기: B,C',N
        proj_query = proj_query.permute(0, 2, 1)  # 전치 조작
        proj_key = self.key_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # 크기: B,C',N

        # 곱셈
        S = torch.bmm(proj_query, proj_key)  # bmm: 배치별 행렬곱

        # 규격화
        attention_map_T = self.softmax(S)  # i행 방향의 합을 1로 하는 소프트맥스 함수
        attention_map = attention_map_T.permute(0, 2, 1)  # 전치

        # Self-Attention Map을 계산
        proj_value = self.value_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # 크기: B,C,N
        o = torch.bmm(proj_value, attention_map.permute(
            0, 2, 1))  # Attention Map을 전치하여 곱함

        # Self-Attention Map o의 텐서 크기를 X로 준비하여 출력으로 한다
        o = o.view(X.shape[0], X.shape[1], X.shape[2], X.shape[3])
        out = x+self.gamma*o

        return out, attention_map

# %% [markdown]
# ## 2-2. Generator

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            # Spectral Normalization을 추가
            nn.utils.spectral_norm(nn.ConvTranspose2d(z_dim, image_size * 8,
                                                      kernel_size=4, stride=1)),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            # Spectral Normalization을 추가
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 8, image_size * 4,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            # Spectral Normalization을 추가
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 4, image_size * 2,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        # Self-Attention층을 추가
        self.self_attntion1 = Self_Attention(in_dim=image_size * 2)

        self.layer4 = nn.Sequential(
            # Spectral Normalization을 추가
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 2, image_size,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        # Self-Attention층을 추가
        self.self_attntion2 = Self_Attention(in_dim=image_size)

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 흑백 이미지이므로 출력 채널은 1


    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attntion1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attntion2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %%
# 동작 확인
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 난수 입력
input_z = torch.randn(1, 20)

# 텐서 크기를 (1, 20, 1, 1)으로 변형
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 가짜 이미지 출력
fake_images, attention_map1, attention_map2 = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# ## 2-3. Discriminator

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            # Spectral Normalization을 추가
            nn.utils.spectral_norm(nn.Conv2d(1, image_size, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))
        # 흑백 이미지이므로 출력 채널은 1

        self.layer2 = nn.Sequential(
            # Spectral Normalization을 추가
            nn.utils.spectral_norm(nn.Conv2d(image_size, image_size*2, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            # Spectral Normalization을 추가
            nn.utils.spectral_norm(nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        # Self-Attention층을 추가
        self.self_attntion1 = Self_Attention(in_dim=image_size*4)

        self.layer4 = nn.Sequential(
            # Spectral Normalization을 추가
            nn.utils.spectral_norm(nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        # Self-Attention층을 추가
        self.self_attntion2 = Self_Attention(in_dim=image_size*8)

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attntion1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attntion2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %%
# 동작 확인
D = Discriminator(z_dim=20, image_size=64)

# 가짜 이미지 생성
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images, _, _ = G(input_z)

# 가짜 이미지를 D에 입력
d_out, attention_map1, attention_map2 = D(fake_images)

# 출력 d_out에 Sigmoid를 곱해 0에서 1로 변환
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5001]]]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# ## 2-4. DataLoader

# %%
def make_datapath_list():
    """학습 및 검증 화상 데이터와 어노테이션 데이터의 파일 경로 리스트를 작성한다. """

    train_img_list = list()  # 화상 파일 경로를 저장

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """화상의 전처리 클래스"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """화상의 Dataset 클래스. PyTorch의 Dataset 클래스를 상속"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''화상 매수를 반환한다'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''전처리한 화상의 Tensor 형식 데이터 취득'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [높이][폭]흑백

        # 화상 전처리
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoader 작성과 동작 확인

# 파일 리스트를 작성
train_img_list=make_datapath_list()

# Dataset 작성
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoader 작성
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 동작 확인
batch_iterator = iter(train_dataloader)  # 반복자로 변환
imges = next(batch_iterator)  # 1번째 요소를 꺼낸다
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# ## 2-5. Training

# %%
# 모델을 학습시키는 함수를 작성
def train_model(G, D, dataloader, num_epochs):

    # GPU 확인
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("사용 장치: ", device)

    # 최적화 기법 설정
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 오차함수 정의 -> hinge version of the adversarial loss로 변경
    # criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # 파라미터 하드코딩
    z_dim = 20
    mini_batch_size = 64

    # 네트워크를 GPU로
    G.to(device)
    D.to(device)

    G.train()  # 모델을 훈련 모드로
    D.train()  # 모델을 훈련 모드로

    # 네트워크가 어느 정도 고정되면, 고속화시킨다
    torch.backends.cudnn.benchmark = True

    # 화상의 매수
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # 반복 카운터 설정
    iteration = 1
    logs = []

    # epoch 루프
    for epoch in range(num_epochs):

        # 개시 시간을 저장
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epoch의 손실합
        epoch_d_loss = 0.0  # epoch의 손실합

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('(train)')

        # 데이터 로더에서 minibatch씩 꺼내는 루프
        for imges in dataloader:

            # --------------------
            # 1. Discriminator 학습
            # --------------------
            # 미니 배치 크기가 1이면, 배치 노멀라이제이션에서 에러가 발생하므로 피한다
            if imges.size()[0] == 1:
                continue

            # GPU가 사용 가능하면 GPU로 데이터를 보낸다
            imges = imges.to(device)

            # 정답 라벨과 가짜 라벨 작성
            # epoch의 마지막 반복은 미니 배치 수가 줄어든다
            mini_batch_size = imges.size()[0]
            #label_real = torch.full((mini_batch_size,), 1).to(device)
            #label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 진짜 이미지 판정
            d_out_real, _, _ = D(imges)

            # 가짜 이미지 생성해 판정
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z)
            d_out_fake, _, _ = D(fake_images)

            # 오차를 계산 -> hinge version of the adversarial loss로 변경
            # d_loss_real = criterion(d_out_real.view(-1), label_real)
            # d_loss_fake = criterion(d_out_fake.view(-1), label_fake)

            d_loss_real = torch.nn.ReLU()(1.0 - d_out_real).mean()
            # 오차 d_out_real이 1이상에서 오차 0이 된다. d_out_real>1에서,
            # 1.0 - d_out_real가 음수이면 ReLU로 0으로 한다

            d_loss_fake = torch.nn.ReLU()(1.0 + d_out_fake).mean()
            # 오차 d_out_fake가 -1 이하이면 오차 0이 된다. d_out_fake<-1에서,
            # 1.0 + d_out_real가 음수이면 ReLU로 0으로 한다

            d_loss = d_loss_real + d_loss_fake

            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generator 학습
            # --------------------
            # 가짜 화상을 생성해 판정
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z)
            d_out_fake, _, _ = D(fake_images)

            # 오차를 계산→hinge version of the adversarial loss로 변경
            #g_loss = criterion(d_out_fake.view(-1), label_real)
            g_loss = - d_out_fake.mean()

            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 기록
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epoch의 phase별 loss와 정답률
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    # print("총 반복 횟수: ", iteration)

    return G, D

# %%
# 네트워크 초기화
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2d ,  ConvTranspose2d 초기화
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2d 초기화
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 초기화 실시
G.apply(weights_init)
D.apply(weights_init)

print("네트워크 초기화 완료")
# Out:
# 네트워크 초기화 완료

# %%
# 학습 및 검증 실행
num_epochs = 300
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 사용 장치:  cuda:0
# -------------
# Epoch 0/300
# -------------
# (train)
# -------------
# epoch 0 || Epoch_D_Loss:0.1577 ||Epoch_G_Loss:0.0187
# timer:  106.8512 sec.
# -------------
# Epoch 1/300
# -------------
# (train)
# -------------
# epoch 1 || Epoch_D_Loss:0.1227 ||Epoch_G_Loss:0.0732
# timer:  1.5629 sec.
# -------------
# Epoch 2/300
# -------------
# (train)
# -------------
# epoch 2 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.0359
# timer:  1.5664 sec.
# -------------
# Epoch 3/300
# -------------
# (train)
# -------------
# epoch 3 || Epoch_D_Loss:0.1230 ||Epoch_G_Loss:-0.0035
# timer:  1.5793 sec.
# -------------
# Epoch 4/300
# -------------
# (train)
# -------------
# epoch 4 || Epoch_D_Loss:0.0900 ||Epoch_G_Loss:0.0324
# timer:  1.5776 sec.
# -------------
# Epoch 5/300
# -------------
# (train)
# -------------
# epoch 5 || Epoch_D_Loss:0.0604 ||Epoch_G_Loss:0.0968
# timer:  1.5578 sec.
# -------------
# Epoch 6/300
# -------------
# (train)
# -------------
# epoch 6 || Epoch_D_Loss:0.0001 ||Epoch_G_Loss:0.1406
# timer:  1.5436 sec.
# -------------
# Epoch 7/300
# -------------
# (train)
# -------------
# epoch 7 || Epoch_D_Loss:0.0001 ||Epoch_G_Loss:0.1499
# timer:  1.5375 sec.
# -------------
# Epoch 8/300
# -------------
# (train)
# -------------
# epoch 8 || Epoch_D_Loss:0.0758 ||Epoch_G_Loss:0.1217
# timer:  1.5431 sec.
# -------------
# Epoch 9/300
# -------------
# (train)
# -------------
# epoch 9 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:0.2133
# timer:  1.5575 sec.
# -------------
# Epoch 10/300
# -------------
# (train)
# -------------
# epoch 10 || Epoch_D_Loss:0.1600 ||Epoch_G_Loss:0.0056
# timer:  1.5562 sec.
# -------------
# Epoch 11/300
# -------------
# (train)
# -------------
# epoch 11 || Epoch_D_Loss:0.0962 ||Epoch_G_Loss:0.0797
# timer:  1.5654 sec.
# -------------
# Epoch 12/300
# -------------
# (train)
# -------------
# epoch 12 || Epoch_D_Loss:0.0634 ||Epoch_G_Loss:0.1051
# timer:  1.5442 sec.
# -------------
# Epoch 13/300
# -------------
# (train)
# -------------
# epoch 13 || Epoch_D_Loss:0.0919 ||Epoch_G_Loss:0.0917
# timer:  1.5524 sec.
# -------------
# Epoch 14/300
# -------------
# (train)
# -------------
# epoch 14 || Epoch_D_Loss:0.0820 ||Epoch_G_Loss:0.0849
# timer:  1.5604 sec.
# -------------
# Epoch 15/300
# -------------
# (train)
# -------------
# epoch 15 || Epoch_D_Loss:0.0610 ||Epoch_G_Loss:0.1353
# timer:  1.5525 sec.
# -------------
# Epoch 16/300
# -------------
# (train)
# -------------
# epoch 16 || Epoch_D_Loss:0.0834 ||Epoch_G_Loss:0.0908
# timer:  1.5535 sec.
# -------------
# Epoch 17/300
# -------------
# (train)
# -------------
# epoch 17 || Epoch_D_Loss:0.0734 ||Epoch_G_Loss:0.1391
# timer:  1.5663 sec.
# -------------
# Epoch 18/300
# -------------
# (train)
# -------------
# epoch 18 || Epoch_D_Loss:0.0889 ||Epoch_G_Loss:0.1114
# timer:  1.5708 sec.
# -------------
# Epoch 19/300
# -------------
# (train)
# -------------
# epoch 19 || Epoch_D_Loss:0.1011 ||Epoch_G_Loss:0.1063
# timer:  1.5873 sec.
# -------------
# Epoch 20/300
# -------------
# (train)
# -------------
# epoch 20 || Epoch_D_Loss:0.1051 ||Epoch_G_Loss:0.0651
# timer:  1.5789 sec.
# -------------
# Epoch 21/300
# -------------
# (train)
# -------------
# epoch 21 || Epoch_D_Loss:0.1163 ||Epoch_G_Loss:0.1050
# timer:  1.5852 sec.
# -------------
# Epoch 22/300
# -------------
# (train)
# -------------
# epoch 22 || Epoch_D_Loss:0.0993 ||Epoch_G_Loss:0.0584
# timer:  1.5705 sec.
# -------------
# Epoch 23/300
# -------------
# (train)
# -------------
# epoch 23 || Epoch_D_Loss:0.0992 ||Epoch_G_Loss:0.1049
# timer:  1.5845 sec.
# -------------
# Epoch 24/300
# -------------
# (train)
# -------------
# epoch 24 || Epoch_D_Loss:0.1312 ||Epoch_G_Loss:0.0709
# timer:  1.5860 sec.
# -------------
# Epoch 25/300
# -------------
# (train)
# -------------
# epoch 25 || Epoch_D_Loss:0.1378 ||Epoch_G_Loss:0.0455
# timer:  1.5850 sec.
# -------------
# Epoch 26/300
# -------------
# (train)
# -------------
# epoch 26 || Epoch_D_Loss:0.1428 ||Epoch_G_Loss:0.0989
# timer:  1.5712 sec.
# -------------
# Epoch 27/300
# -------------
# (train)
# -------------
# epoch 27 || Epoch_D_Loss:0.1502 ||Epoch_G_Loss:0.0539
# timer:  1.5796 sec.
# -------------
# Epoch 28/300
# -------------
# (train)
# -------------
# epoch 28 || Epoch_D_Loss:0.1202 ||Epoch_G_Loss:0.1134
# timer:  1.5945 sec.
# -------------
# Epoch 29/300
# -------------
# (train)
# -------------
# epoch 29 || Epoch_D_Loss:0.1626 ||Epoch_G_Loss:0.0689
# timer:  1.5884 sec.
# -------------
# Epoch 30/300
# -------------
# (train)
# -------------
# epoch 30 || Epoch_D_Loss:0.1857 ||Epoch_G_Loss:0.0942
# timer:  1.5931 sec.
# -------------
# Epoch 31/300
# -------------
# (train)
# -------------
# epoch 31 || Epoch_D_Loss:0.1743 ||Epoch_G_Loss:0.0915
# timer:  1.5847 sec.
# -------------
# Epoch 32/300
# -------------
# (train)
# -------------
# epoch 32 || Epoch_D_Loss:0.1140 ||Epoch_G_Loss:0.0230
# timer:  1.6126 sec.
# -------------
# Epoch 33/300
# -------------
# (train)
# -------------
# epoch 33 || Epoch_D_Loss:0.2184 ||Epoch_G_Loss:0.0173
# timer:  1.5807 sec.
# -------------
# Epoch 34/300
# -------------
# (train)
# -------------
# epoch 34 || Epoch_D_Loss:0.1288 ||Epoch_G_Loss:0.1027
# timer:  1.5960 sec.
# -------------
# Epoch 35/300
# -------------
# (train)
# -------------
# epoch 35 || Epoch_D_Loss:0.2127 ||Epoch_G_Loss:0.0371
# timer:  1.5949 sec.
# -------------
# Epoch 36/300
# -------------
# (train)
# -------------
# epoch 36 || Epoch_D_Loss:0.1684 ||Epoch_G_Loss:0.0365
# timer:  1.5876 sec.
# -------------
# Epoch 37/300
# -------------
# (train)
# -------------
# epoch 37 || Epoch_D_Loss:0.1720 ||Epoch_G_Loss:0.0517
# timer:  1.6057 sec.
# -------------
# Epoch 38/300
# -------------
# (train)
# -------------
# epoch 38 || Epoch_D_Loss:0.1942 ||Epoch_G_Loss:0.0159
# timer:  1.5928 sec.
# -------------
# Epoch 39/300
# -------------
# (train)
# -------------
# epoch 39 || Epoch_D_Loss:0.1984 ||Epoch_G_Loss:0.0214
# timer:  1.6422 sec.
# -------------
# Epoch 40/300
# -------------
# (train)
# -------------
# epoch 40 || Epoch_D_Loss:0.1807 ||Epoch_G_Loss:0.0290
# timer:  1.6075 sec.
# -------------
# Epoch 41/300
# -------------
# (train)
# -------------
# epoch 41 || Epoch_D_Loss:0.2088 ||Epoch_G_Loss:0.0105
# timer:  1.5960 sec.
# -------------
# Epoch 42/300
# -------------
# (train)
# -------------
# epoch 42 || Epoch_D_Loss:0.1880 ||Epoch_G_Loss:0.0409
# timer:  1.6239 sec.
# -------------
# Epoch 43/300
# -------------
# (train)
# -------------
# epoch 43 || Epoch_D_Loss:0.2090 ||Epoch_G_Loss:0.0196
# timer:  1.6000 sec.
# -------------
# Epoch 44/300
# -------------
# (train)
# -------------
# epoch 44 || Epoch_D_Loss:0.1998 ||Epoch_G_Loss:0.0397
# timer:  1.6037 sec.
# -------------
# Epoch 45/300
# -------------
# (train)
# -------------
# epoch 45 || Epoch_D_Loss:0.1943 ||Epoch_G_Loss:0.0481
# timer:  1.6218 sec.
# -------------
# Epoch 46/300
# -------------
# (train)
# -------------
# epoch 46 || Epoch_D_Loss:0.2056 ||Epoch_G_Loss:0.0206
# timer:  1.6102 sec.
# -------------
# Epoch 47/300
# -------------
# (train)
# -------------
# epoch 47 || Epoch_D_Loss:0.1904 ||Epoch_G_Loss:0.0426
# timer:  1.6009 sec.
# -------------
# Epoch 48/300
# -------------
# (train)
# -------------
# epoch 48 || Epoch_D_Loss:0.1974 ||Epoch_G_Loss:0.0190
# timer:  1.6207 sec.
# -------------
# Epoch 49/300
# -------------
# (train)
# -------------
# epoch 49 || Epoch_D_Loss:0.1855 ||Epoch_G_Loss:0.0672
# timer:  1.6259 sec.
# -------------
# Epoch 50/300
# -------------
# (train)
# -------------
# epoch 50 || Epoch_D_Loss:0.2171 ||Epoch_G_Loss:-0.0131
# timer:  1.6202 sec.
# -------------
# Epoch 51/300
# -------------
# (train)
# -------------
# epoch 51 || Epoch_D_Loss:0.1972 ||Epoch_G_Loss:0.0269
# timer:  1.6247 sec.
# -------------
# Epoch 52/300
# -------------
# (train)
# -------------
# epoch 52 || Epoch_D_Loss:0.1904 ||Epoch_G_Loss:0.0466
# timer:  1.6104 sec.
# -------------
# Epoch 53/300
# -------------
# (train)
# -------------
# epoch 53 || Epoch_D_Loss:0.1988 ||Epoch_G_Loss:0.0088
# timer:  1.6342 sec.
# -------------
# Epoch 54/300
# -------------
# (train)
# -------------
# epoch 54 || Epoch_D_Loss:0.1784 ||Epoch_G_Loss:0.0790
# timer:  1.6332 sec.
# -------------
# Epoch 55/300
# -------------
# (train)
# -------------
# epoch 55 || Epoch_D_Loss:0.2022 ||Epoch_G_Loss:0.0103
# timer:  1.6227 sec.
# -------------
# Epoch 56/300
# -------------
# (train)
# -------------
# epoch 56 || Epoch_D_Loss:0.1818 ||Epoch_G_Loss:0.0451
# timer:  1.6447 sec.
# -------------
# Epoch 57/300
# -------------
# (train)
# -------------
# epoch 57 || Epoch_D_Loss:0.1807 ||Epoch_G_Loss:0.0384
# timer:  1.6206 sec.
# -------------
# Epoch 58/300
# -------------
# (train)
# -------------
# epoch 58 || Epoch_D_Loss:0.1865 ||Epoch_G_Loss:0.0367
# timer:  1.6472 sec.
# -------------
# Epoch 59/300
# -------------
# (train)
# -------------
# epoch 59 || Epoch_D_Loss:0.1725 ||Epoch_G_Loss:0.0829
# timer:  1.6289 sec.
# -------------
# Epoch 60/300
# -------------
# (train)
# -------------
# epoch 60 || Epoch_D_Loss:0.2003 ||Epoch_G_Loss:0.0225
# timer:  1.6263 sec.
# -------------
# Epoch 61/300
# -------------
# (train)
# -------------
# epoch 61 || Epoch_D_Loss:0.1874 ||Epoch_G_Loss:0.0178
# timer:  1.6193 sec.
# -------------
# Epoch 62/300
# -------------
# (train)
# -------------
# epoch 62 || Epoch_D_Loss:0.1846 ||Epoch_G_Loss:0.0469
# timer:  1.6377 sec.
# -------------
# Epoch 63/300
# -------------
# (train)
# -------------
# epoch 63 || Epoch_D_Loss:0.1788 ||Epoch_G_Loss:0.0248
# timer:  1.6315 sec.
# -------------
# Epoch 64/300
# -------------
# (train)
# -------------
# epoch 64 || Epoch_D_Loss:0.1923 ||Epoch_G_Loss:0.0196
# timer:  1.6262 sec.
# -------------
# Epoch 65/300
# -------------
# (train)
# -------------
# epoch 65 || Epoch_D_Loss:0.1838 ||Epoch_G_Loss:0.0562
# timer:  1.6180 sec.
# -------------
# Epoch 66/300
# -------------
# (train)
# -------------
# epoch 66 || Epoch_D_Loss:0.1768 ||Epoch_G_Loss:0.0375
# timer:  1.6397 sec.
# -------------
# Epoch 67/300
# -------------
# (train)
# -------------
# epoch 67 || Epoch_D_Loss:0.1961 ||Epoch_G_Loss:0.0480
# timer:  1.6158 sec.
# -------------
# Epoch 68/300
# -------------
# (train)
# -------------
# epoch 68 || Epoch_D_Loss:0.1917 ||Epoch_G_Loss:0.0281
# timer:  1.6462 sec.
# -------------
# Epoch 69/300
# -------------
# (train)
# -------------
# epoch 69 || Epoch_D_Loss:0.1751 ||Epoch_G_Loss:0.0456
# timer:  1.6407 sec.
# -------------
# Epoch 70/300
# -------------
# (train)
# -------------
# epoch 70 || Epoch_D_Loss:0.1686 ||Epoch_G_Loss:0.0741
# timer:  1.6590 sec.
# -------------
# Epoch 71/300
# -------------
# (train)
# -------------
# epoch 71 || Epoch_D_Loss:0.1958 ||Epoch_G_Loss:0.0216
# timer:  1.6517 sec.
# -------------
# Epoch 72/300
# -------------
# (train)
# -------------
# epoch 72 || Epoch_D_Loss:0.1869 ||Epoch_G_Loss:0.0447
# timer:  1.6404 sec.
# -------------
# Epoch 73/300
# -------------
# (train)
# -------------
# epoch 73 || Epoch_D_Loss:0.1647 ||Epoch_G_Loss:0.0335
# timer:  1.6405 sec.
# -------------
# Epoch 74/300
# -------------
# (train)
# -------------
# epoch 74 || Epoch_D_Loss:0.1905 ||Epoch_G_Loss:0.0345
# timer:  1.6372 sec.
# -------------
# Epoch 75/300
# -------------
# (train)
# -------------
# epoch 75 || Epoch_D_Loss:0.1869 ||Epoch_G_Loss:0.0515
# timer:  1.6528 sec.
# -------------
# Epoch 76/300
# -------------
# (train)
# -------------
# epoch 76 || Epoch_D_Loss:0.1919 ||Epoch_G_Loss:0.0169
# timer:  1.6470 sec.
# -------------
# Epoch 77/300
# -------------
# (train)
# -------------
# epoch 77 || Epoch_D_Loss:0.1775 ||Epoch_G_Loss:0.0388
# timer:  1.6501 sec.
# -------------
# Epoch 78/300
# -------------
# (train)
# -------------
# epoch 78 || Epoch_D_Loss:0.1842 ||Epoch_G_Loss:0.0409
# timer:  1.6435 sec.
# -------------
# Epoch 79/300
# -------------
# (train)
# -------------
# epoch 79 || Epoch_D_Loss:0.1876 ||Epoch_G_Loss:0.0123
# timer:  1.6573 sec.
# -------------
# Epoch 80/300
# -------------
# (train)
# -------------
# epoch 80 || Epoch_D_Loss:0.1771 ||Epoch_G_Loss:0.0361
# timer:  1.6558 sec.
# -------------
# Epoch 81/300
# -------------
# (train)
# -------------
# epoch 81 || Epoch_D_Loss:0.1896 ||Epoch_G_Loss:0.0380
# timer:  1.6559 sec.
# -------------
# Epoch 82/300
# -------------
# (train)
# -------------
# epoch 82 || Epoch_D_Loss:0.1658 ||Epoch_G_Loss:0.0395
# timer:  1.6881 sec.
# -------------
# Epoch 83/300
# -------------
# (train)
# -------------
# epoch 83 || Epoch_D_Loss:0.2028 ||Epoch_G_Loss:0.0329
# timer:  1.6592 sec.
# -------------
# Epoch 84/300
# -------------
# (train)
# -------------
# epoch 84 || Epoch_D_Loss:0.1945 ||Epoch_G_Loss:0.0564
# timer:  1.6718 sec.
# -------------
# Epoch 85/300
# -------------
# (train)
# -------------
# epoch 85 || Epoch_D_Loss:0.1699 ||Epoch_G_Loss:0.0230
# timer:  1.6594 sec.
# -------------
# Epoch 86/300
# -------------
# (train)
# -------------
# epoch 86 || Epoch_D_Loss:0.1820 ||Epoch_G_Loss:0.0367
# timer:  1.6742 sec.
# -------------
# Epoch 87/300
# -------------
# (train)
# -------------
# epoch 87 || Epoch_D_Loss:0.1745 ||Epoch_G_Loss:0.0436
# timer:  1.6543 sec.
# -------------
# Epoch 88/300
# -------------
# (train)
# -------------
# epoch 88 || Epoch_D_Loss:0.1752 ||Epoch_G_Loss:0.0738
# timer:  1.6628 sec.
# -------------
# Epoch 89/300
# -------------
# (train)
# -------------
# epoch 89 || Epoch_D_Loss:0.1863 ||Epoch_G_Loss:0.0058
# timer:  1.6567 sec.
# -------------
# Epoch 90/300
# -------------
# (train)
# -------------
# epoch 90 || Epoch_D_Loss:0.1858 ||Epoch_G_Loss:0.0404
# timer:  1.6599 sec.
# -------------
# Epoch 91/300
# -------------
# (train)
# -------------
# epoch 91 || Epoch_D_Loss:0.1824 ||Epoch_G_Loss:0.0142
# timer:  1.6601 sec.
# -------------
# Epoch 92/300
# -------------
# (train)
# -------------
# epoch 92 || Epoch_D_Loss:0.1738 ||Epoch_G_Loss:0.0496
# timer:  1.6377 sec.
# -------------
# Epoch 93/300
# -------------
# (train)
# -------------
# epoch 93 || Epoch_D_Loss:0.1720 ||Epoch_G_Loss:0.0381
# timer:  1.6629 sec.
# -------------
# Epoch 94/300
# -------------
# (train)
# -------------
# epoch 94 || Epoch_D_Loss:0.1868 ||Epoch_G_Loss:0.0250
# timer:  1.6629 sec.
# -------------
# Epoch 95/300
# -------------
# (train)
# -------------
# epoch 95 || Epoch_D_Loss:0.1759 ||Epoch_G_Loss:0.0464
# timer:  1.6424 sec.
# -------------
# Epoch 96/300
# -------------
# (train)
# -------------
# epoch 96 || Epoch_D_Loss:0.1980 ||Epoch_G_Loss:0.0267
# timer:  1.6599 sec.
# -------------
# Epoch 97/300
# -------------
# (train)
# -------------
# epoch 97 || Epoch_D_Loss:0.1832 ||Epoch_G_Loss:0.0375
# timer:  1.6495 sec.
# -------------
# Epoch 98/300
# -------------
# (train)
# -------------
# epoch 98 || Epoch_D_Loss:0.1688 ||Epoch_G_Loss:0.0511
# timer:  1.6426 sec.
# -------------
# Epoch 99/300
# -------------
# (train)
# -------------
# epoch 99 || Epoch_D_Loss:0.1908 ||Epoch_G_Loss:0.0676
# timer:  1.6412 sec.
# -------------
# Epoch 100/300
# -------------
# (train)
# -------------
# epoch 100 || Epoch_D_Loss:0.1730 ||Epoch_G_Loss:0.0335
# timer:  1.6509 sec.
# -------------
# Epoch 101/300
# -------------
# (train)
# -------------
# epoch 101 || Epoch_D_Loss:0.1776 ||Epoch_G_Loss:0.0379
# timer:  1.6353 sec.
# -------------
# Epoch 102/300
# -------------
# (train)
# -------------
# epoch 102 || Epoch_D_Loss:0.1711 ||Epoch_G_Loss:0.0473
# timer:  1.6593 sec.
# -------------
# Epoch 103/300
# -------------
# (train)
# -------------
# epoch 103 || Epoch_D_Loss:0.1781 ||Epoch_G_Loss:0.0231
# timer:  1.6412 sec.
# -------------
# Epoch 104/300
# -------------
# (train)
# -------------
# epoch 104 || Epoch_D_Loss:0.1814 ||Epoch_G_Loss:0.0163
# timer:  1.6467 sec.
# -------------
# Epoch 105/300
# -------------
# (train)
# -------------
# epoch 105 || Epoch_D_Loss:0.1677 ||Epoch_G_Loss:0.0313
# timer:  1.6270 sec.
# -------------
# Epoch 106/300
# -------------
# (train)
# -------------
# epoch 106 || Epoch_D_Loss:0.1887 ||Epoch_G_Loss:0.0325
# timer:  1.6515 sec.
# -------------
# Epoch 107/300
# -------------
# (train)
# -------------
# epoch 107 || Epoch_D_Loss:0.1826 ||Epoch_G_Loss:0.0347
# timer:  1.6349 sec.
# -------------
# Epoch 108/300
# -------------
# (train)
# -------------
# epoch 108 || Epoch_D_Loss:0.1740 ||Epoch_G_Loss:0.0393
# timer:  1.6625 sec.
# -------------
# Epoch 109/300
# -------------
# (train)
# -------------
# epoch 109 || Epoch_D_Loss:0.1730 ||Epoch_G_Loss:0.0328
# timer:  1.6236 sec.
# -------------
# Epoch 110/300
# -------------
# (train)
# -------------
# epoch 110 || Epoch_D_Loss:0.1664 ||Epoch_G_Loss:0.0268
# timer:  1.6302 sec.
# -------------
# Epoch 111/300
# -------------
# (train)
# -------------
# epoch 111 || Epoch_D_Loss:0.1641 ||Epoch_G_Loss:0.0540
# timer:  1.6431 sec.
# -------------
# Epoch 112/300
# -------------
# (train)
# -------------
# epoch 112 || Epoch_D_Loss:0.1767 ||Epoch_G_Loss:0.0298
# timer:  1.6318 sec.
# -------------
# Epoch 113/300
# -------------
# (train)
# -------------
# epoch 113 || Epoch_D_Loss:0.1719 ||Epoch_G_Loss:0.0496
# timer:  1.6348 sec.
# -------------
# Epoch 114/300
# -------------
# (train)
# -------------
# epoch 114 || Epoch_D_Loss:0.1699 ||Epoch_G_Loss:0.0282
# timer:  1.6183 sec.
# -------------
# Epoch 115/300
# -------------
# (train)
# -------------
# epoch 115 || Epoch_D_Loss:0.1661 ||Epoch_G_Loss:0.0398
# timer:  1.6314 sec.
# -------------
# Epoch 116/300
# -------------
# (train)
# -------------
# epoch 116 || Epoch_D_Loss:0.1764 ||Epoch_G_Loss:0.0351
# timer:  1.6376 sec.
# -------------
# Epoch 117/300
# -------------
# (train)
# -------------
# epoch 117 || Epoch_D_Loss:0.1751 ||Epoch_G_Loss:0.0627
# timer:  1.6438 sec.
# -------------
# Epoch 118/300
# -------------
# (train)
# -------------
# epoch 118 || Epoch_D_Loss:0.1681 ||Epoch_G_Loss:0.0367
# timer:  1.6322 sec.
# -------------
# Epoch 119/300
# -------------
# (train)
# -------------
# epoch 119 || Epoch_D_Loss:0.1654 ||Epoch_G_Loss:0.0385
# timer:  1.6369 sec.
# -------------
# Epoch 120/300
# -------------
# (train)
# -------------
# epoch 120 || Epoch_D_Loss:0.1706 ||Epoch_G_Loss:0.0582
# timer:  1.6440 sec.
# -------------
# Epoch 121/300
# -------------
# (train)
# -------------
# epoch 121 || Epoch_D_Loss:0.1603 ||Epoch_G_Loss:0.0508
# timer:  1.6323 sec.
# -------------
# Epoch 122/300
# -------------
# (train)
# -------------
# epoch 122 || Epoch_D_Loss:0.1821 ||Epoch_G_Loss:0.0199
# timer:  1.6334 sec.
# -------------
# Epoch 123/300
# -------------
# (train)
# -------------
# epoch 123 || Epoch_D_Loss:0.1561 ||Epoch_G_Loss:0.0670
# timer:  1.6303 sec.
# -------------
# Epoch 124/300
# -------------
# (train)
# -------------
# epoch 124 || Epoch_D_Loss:0.1748 ||Epoch_G_Loss:0.0257
# timer:  1.6366 sec.
# -------------
# Epoch 125/300
# -------------
# (train)
# -------------
# epoch 125 || Epoch_D_Loss:0.1720 ||Epoch_G_Loss:0.0274
# timer:  1.6358 sec.
# -------------
# Epoch 126/300
# -------------
# (train)
# -------------
# epoch 126 || Epoch_D_Loss:0.1642 ||Epoch_G_Loss:0.0592
# timer:  1.6377 sec.
# -------------
# Epoch 127/300
# -------------
# (train)
# -------------
# epoch 127 || Epoch_D_Loss:0.1608 ||Epoch_G_Loss:0.0513
# timer:  1.6585 sec.
# -------------
# Epoch 128/300
# -------------
# (train)
# -------------
# epoch 128 || Epoch_D_Loss:0.1695 ||Epoch_G_Loss:0.0424
# timer:  1.6526 sec.
# -------------
# Epoch 129/300
# -------------
# (train)
# -------------
# epoch 129 || Epoch_D_Loss:0.1766 ||Epoch_G_Loss:0.0324
# timer:  1.6611 sec.
# -------------
# Epoch 130/300
# -------------
# (train)
# -------------
# epoch 130 || Epoch_D_Loss:0.1668 ||Epoch_G_Loss:0.0290
# timer:  1.6461 sec.
# -------------
# Epoch 131/300
# -------------
# (train)
# -------------
# epoch 131 || Epoch_D_Loss:0.1537 ||Epoch_G_Loss:0.0550
# timer:  1.6548 sec.
# -------------
# Epoch 132/300
# -------------
# (train)
# -------------
# epoch 132 || Epoch_D_Loss:0.1702 ||Epoch_G_Loss:0.0371
# timer:  1.6331 sec.
# -------------
# Epoch 133/300
# -------------
# (train)
# -------------
# epoch 133 || Epoch_D_Loss:0.1552 ||Epoch_G_Loss:0.0562
# timer:  1.6711 sec.
# -------------
# Epoch 134/300
# -------------
# (train)
# -------------
# epoch 134 || Epoch_D_Loss:0.1516 ||Epoch_G_Loss:0.0449
# timer:  1.6434 sec.
# -------------
# Epoch 135/300
# -------------
# (train)
# -------------
# epoch 135 || Epoch_D_Loss:0.1685 ||Epoch_G_Loss:0.0235
# timer:  1.6434 sec.
# -------------
# Epoch 136/300
# -------------
# (train)
# -------------
# epoch 136 || Epoch_D_Loss:0.1581 ||Epoch_G_Loss:0.0316
# timer:  1.6480 sec.
# -------------
# Epoch 137/300
# -------------
# (train)
# -------------
# epoch 137 || Epoch_D_Loss:0.1706 ||Epoch_G_Loss:0.0332
# timer:  1.6515 sec.
# -------------
# Epoch 138/300
# -------------
# (train)
# -------------
# epoch 138 || Epoch_D_Loss:0.1420 ||Epoch_G_Loss:0.0774
# timer:  1.6529 sec.
# -------------
# Epoch 139/300
# -------------
# (train)
# -------------
# epoch 139 || Epoch_D_Loss:0.1687 ||Epoch_G_Loss:0.0156
# timer:  1.6883 sec.
# -------------
# Epoch 140/300
# -------------
# (train)
# -------------
# epoch 140 || Epoch_D_Loss:0.1669 ||Epoch_G_Loss:0.0458
# timer:  1.6746 sec.
# -------------
# Epoch 141/300
# -------------
# (train)
# -------------
# epoch 141 || Epoch_D_Loss:0.1558 ||Epoch_G_Loss:0.0550
# timer:  1.6588 sec.
# -------------
# Epoch 142/300
# -------------
# (train)
# -------------
# epoch 142 || Epoch_D_Loss:0.1647 ||Epoch_G_Loss:0.0393
# timer:  1.6622 sec.
# -------------
# Epoch 143/300
# -------------
# (train)
# -------------
# epoch 143 || Epoch_D_Loss:0.1576 ||Epoch_G_Loss:0.0435
# timer:  1.6532 sec.
# -------------
# Epoch 144/300
# -------------
# (train)
# -------------
# epoch 144 || Epoch_D_Loss:0.1412 ||Epoch_G_Loss:0.0438
# timer:  1.6509 sec.
# -------------
# Epoch 145/300
# -------------
# (train)
# -------------
# epoch 145 || Epoch_D_Loss:0.1688 ||Epoch_G_Loss:0.0508
# timer:  1.6466 sec.
# -------------
# Epoch 146/300
# -------------
# (train)
# -------------
# epoch 146 || Epoch_D_Loss:0.1555 ||Epoch_G_Loss:0.0497
# timer:  1.6522 sec.
# -------------
# Epoch 147/300
# -------------
# (train)
# -------------
# epoch 147 || Epoch_D_Loss:0.1446 ||Epoch_G_Loss:0.0773
# timer:  1.6349 sec.
# -------------
# Epoch 148/300
# -------------
# (train)
# -------------
# epoch 148 || Epoch_D_Loss:0.1588 ||Epoch_G_Loss:0.0326
# timer:  1.6327 sec.
# -------------
# Epoch 149/300
# -------------
# (train)
# -------------
# epoch 149 || Epoch_D_Loss:0.1620 ||Epoch_G_Loss:0.0460
# timer:  1.6457 sec.
# -------------
# Epoch 150/300
# -------------
# (train)
# -------------
# epoch 150 || Epoch_D_Loss:0.1523 ||Epoch_G_Loss:0.0541
# timer:  1.6341 sec.
# -------------
# Epoch 151/300
# -------------
# (train)
# -------------
# epoch 151 || Epoch_D_Loss:0.1473 ||Epoch_G_Loss:0.0549
# timer:  1.6329 sec.
# -------------
# Epoch 152/300
# -------------
# (train)
# -------------
# epoch 152 || Epoch_D_Loss:0.1392 ||Epoch_G_Loss:0.0546
# timer:  1.6279 sec.
# -------------
# Epoch 153/300
# -------------
# (train)
# -------------
# epoch 153 || Epoch_D_Loss:0.1479 ||Epoch_G_Loss:0.0723
# timer:  1.6266 sec.
# -------------
# Epoch 154/300
# -------------
# (train)
# -------------
# epoch 154 || Epoch_D_Loss:0.1493 ||Epoch_G_Loss:0.0380
# timer:  1.6317 sec.
# -------------
# Epoch 155/300
# -------------
# (train)
# -------------
# epoch 155 || Epoch_D_Loss:0.1470 ||Epoch_G_Loss:0.0630
# timer:  1.6305 sec.
# -------------
# Epoch 156/300
# -------------
# (train)
# -------------
# epoch 156 || Epoch_D_Loss:0.1475 ||Epoch_G_Loss:0.0590
# timer:  1.6513 sec.
# -------------
# Epoch 157/300
# -------------
# (train)
# -------------
# epoch 157 || Epoch_D_Loss:0.1421 ||Epoch_G_Loss:0.0680
# timer:  1.6358 sec.
# -------------
# Epoch 158/300
# -------------
# (train)
# -------------
# epoch 158 || Epoch_D_Loss:0.1563 ||Epoch_G_Loss:0.0405
# timer:  1.6533 sec.
# -------------
# Epoch 159/300
# -------------
# (train)
# -------------
# epoch 159 || Epoch_D_Loss:0.1284 ||Epoch_G_Loss:0.0840
# timer:  1.6370 sec.
# -------------
# Epoch 160/300
# -------------
# (train)
# -------------
# epoch 160 || Epoch_D_Loss:0.1439 ||Epoch_G_Loss:0.0465
# timer:  1.6337 sec.
# -------------
# Epoch 161/300
# -------------
# (train)
# -------------
# epoch 161 || Epoch_D_Loss:0.1432 ||Epoch_G_Loss:0.0641
# timer:  1.6358 sec.
# -------------
# Epoch 162/300
# -------------
# (train)
# -------------
# epoch 162 || Epoch_D_Loss:0.1375 ||Epoch_G_Loss:0.0548
# timer:  1.6291 sec.
# -------------
# Epoch 163/300
# -------------
# (train)
# -------------
# epoch 163 || Epoch_D_Loss:0.1423 ||Epoch_G_Loss:0.0643
# timer:  1.6353 sec.
# -------------
# Epoch 164/300
# -------------
# (train)
# -------------
# epoch 164 || Epoch_D_Loss:0.1303 ||Epoch_G_Loss:0.0785
# timer:  1.6317 sec.
# -------------
# Epoch 165/300
# -------------
# (train)
# -------------
# epoch 165 || Epoch_D_Loss:0.1492 ||Epoch_G_Loss:0.0683
# timer:  1.6375 sec.
# -------------
# Epoch 166/300
# -------------
# (train)
# -------------
# epoch 166 || Epoch_D_Loss:0.1299 ||Epoch_G_Loss:0.0618
# timer:  1.6280 sec.
# -------------
# Epoch 167/300
# -------------
# (train)
# -------------
# epoch 167 || Epoch_D_Loss:0.1386 ||Epoch_G_Loss:0.0903
# timer:  1.6426 sec.
# -------------
# Epoch 168/300
# -------------
# (train)
# -------------
# epoch 168 || Epoch_D_Loss:0.1406 ||Epoch_G_Loss:0.0586
# timer:  1.6270 sec.
# -------------
# Epoch 169/300
# -------------
# (train)
# -------------
# epoch 169 || Epoch_D_Loss:0.1298 ||Epoch_G_Loss:0.0661
# timer:  1.6304 sec.
# -------------
# Epoch 170/300
# -------------
# (train)
# -------------
# epoch 170 || Epoch_D_Loss:0.1309 ||Epoch_G_Loss:0.0701
# timer:  1.6435 sec.
# -------------
# Epoch 171/300
# -------------
# (train)
# -------------
# epoch 171 || Epoch_D_Loss:0.1355 ||Epoch_G_Loss:0.0688
# timer:  1.6427 sec.
# -------------
# Epoch 172/300
# -------------
# (train)
# -------------
# epoch 172 || Epoch_D_Loss:0.1162 ||Epoch_G_Loss:0.0933
# timer:  1.6428 sec.
# -------------
# Epoch 173/300
# -------------
# (train)
# -------------
# epoch 173 || Epoch_D_Loss:0.1429 ||Epoch_G_Loss:0.0618
# timer:  1.6341 sec.
# -------------
# Epoch 174/300
# -------------
# (train)
# -------------
# epoch 174 || Epoch_D_Loss:0.1341 ||Epoch_G_Loss:0.0764
# timer:  1.6421 sec.
# -------------
# Epoch 175/300
# -------------
# (train)
# -------------
# epoch 175 || Epoch_D_Loss:0.1299 ||Epoch_G_Loss:0.0687
# timer:  1.6305 sec.
# -------------
# Epoch 176/300
# -------------
# (train)
# -------------
# epoch 176 || Epoch_D_Loss:0.1378 ||Epoch_G_Loss:0.0791
# timer:  1.6426 sec.
# -------------
# Epoch 177/300
# -------------
# (train)
# -------------
# epoch 177 || Epoch_D_Loss:0.1183 ||Epoch_G_Loss:0.0620
# timer:  1.6264 sec.
# -------------
# Epoch 178/300
# -------------
# (train)
# -------------
# epoch 178 || Epoch_D_Loss:0.1205 ||Epoch_G_Loss:0.1035
# timer:  1.6365 sec.
# -------------
# Epoch 179/300
# -------------
# (train)
# -------------
# epoch 179 || Epoch_D_Loss:0.1313 ||Epoch_G_Loss:0.0655
# timer:  1.6440 sec.
# -------------
# Epoch 180/300
# -------------
# (train)
# -------------
# epoch 180 || Epoch_D_Loss:0.1285 ||Epoch_G_Loss:0.0732
# timer:  1.6520 sec.
# -------------
# Epoch 181/300
# -------------
# (train)
# -------------
# epoch 181 || Epoch_D_Loss:0.1222 ||Epoch_G_Loss:0.0818
# timer:  1.6369 sec.
# -------------
# Epoch 182/300
# -------------
# (train)
# -------------
# epoch 182 || Epoch_D_Loss:0.1191 ||Epoch_G_Loss:0.0725
# timer:  1.6337 sec.
# -------------
# Epoch 183/300
# -------------
# (train)
# -------------
# epoch 183 || Epoch_D_Loss:0.1233 ||Epoch_G_Loss:0.0939
# timer:  1.6329 sec.
# -------------
# Epoch 184/300
# -------------
# (train)
# -------------
# epoch 184 || Epoch_D_Loss:0.1155 ||Epoch_G_Loss:0.0887
# timer:  1.6312 sec.
# -------------
# Epoch 185/300
# -------------
# (train)
# -------------
# epoch 185 || Epoch_D_Loss:0.1195 ||Epoch_G_Loss:0.0902
# timer:  1.6281 sec.
# -------------
# Epoch 186/300
# -------------
# (train)
# -------------
# epoch 186 || Epoch_D_Loss:0.1270 ||Epoch_G_Loss:0.0978
# timer:  1.6395 sec.
# -------------
# Epoch 187/300
# -------------
# (train)
# -------------
# epoch 187 || Epoch_D_Loss:0.1173 ||Epoch_G_Loss:0.0818
# timer:  1.6293 sec.
# -------------
# Epoch 188/300
# -------------
# (train)
# -------------
# epoch 188 || Epoch_D_Loss:0.1189 ||Epoch_G_Loss:0.0840
# timer:  1.6366 sec.
# -------------
# Epoch 189/300
# -------------
# (train)
# -------------
# epoch 189 || Epoch_D_Loss:0.1208 ||Epoch_G_Loss:0.0762
# timer:  1.6244 sec.
# -------------
# Epoch 190/300
# -------------
# (train)
# -------------
# epoch 190 || Epoch_D_Loss:0.1126 ||Epoch_G_Loss:0.0877
# timer:  1.6123 sec.
# -------------
# Epoch 191/300
# -------------
# (train)
# -------------
# epoch 191 || Epoch_D_Loss:0.1057 ||Epoch_G_Loss:0.0810
# timer:  1.6373 sec.
# -------------
# Epoch 192/300
# -------------
# (train)
# -------------
# epoch 192 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.0926
# timer:  1.6322 sec.
# -------------
# Epoch 193/300
# -------------
# (train)
# -------------
# epoch 193 || Epoch_D_Loss:0.1112 ||Epoch_G_Loss:0.0833
# timer:  1.6375 sec.
# -------------
# Epoch 194/300
# -------------
# (train)
# -------------
# epoch 194 || Epoch_D_Loss:0.1153 ||Epoch_G_Loss:0.0946
# timer:  1.6216 sec.
# -------------
# Epoch 195/300
# -------------
# (train)
# -------------
# epoch 195 || Epoch_D_Loss:0.1057 ||Epoch_G_Loss:0.0712
# timer:  1.6329 sec.
# -------------
# Epoch 196/300
# -------------
# (train)
# -------------
# epoch 196 || Epoch_D_Loss:0.1178 ||Epoch_G_Loss:0.0985
# timer:  1.6365 sec.
# -------------
# Epoch 197/300
# -------------
# (train)
# -------------
# epoch 197 || Epoch_D_Loss:0.1093 ||Epoch_G_Loss:0.1033
# timer:  1.6318 sec.
# -------------
# Epoch 198/300
# -------------
# (train)
# -------------
# epoch 198 || Epoch_D_Loss:0.1076 ||Epoch_G_Loss:0.1022
# timer:  1.6380 sec.
# -------------
# Epoch 199/300
# -------------
# (train)
# -------------
# epoch 199 || Epoch_D_Loss:0.0972 ||Epoch_G_Loss:0.0878
# timer:  1.6404 sec.
# -------------
# Epoch 200/300
# -------------
# (train)
# -------------
# epoch 200 || Epoch_D_Loss:0.1067 ||Epoch_G_Loss:0.1048
# timer:  1.6270 sec.
# -------------
# Epoch 201/300
# -------------
# (train)
# -------------
# epoch 201 || Epoch_D_Loss:0.0965 ||Epoch_G_Loss:0.0868
# timer:  1.6348 sec.
# -------------
# Epoch 202/300
# -------------
# (train)
# -------------
# epoch 202 || Epoch_D_Loss:0.1100 ||Epoch_G_Loss:0.1005
# timer:  1.6250 sec.
# -------------
# Epoch 203/300
# -------------
# (train)
# -------------
# epoch 203 || Epoch_D_Loss:0.1024 ||Epoch_G_Loss:0.0877
# timer:  1.6445 sec.
# -------------
# Epoch 204/300
# -------------
# (train)
# -------------
# epoch 204 || Epoch_D_Loss:0.1030 ||Epoch_G_Loss:0.1153
# timer:  1.6257 sec.
# -------------
# Epoch 205/300
# -------------
# (train)
# -------------
# epoch 205 || Epoch_D_Loss:0.1076 ||Epoch_G_Loss:0.1085
# timer:  1.6540 sec.
# -------------
# Epoch 206/300
# -------------
# (train)
# -------------
# epoch 206 || Epoch_D_Loss:0.0860 ||Epoch_G_Loss:0.1066
# timer:  1.6260 sec.
# -------------
# Epoch 207/300
# -------------
# (train)
# -------------
# epoch 207 || Epoch_D_Loss:0.1058 ||Epoch_G_Loss:0.1246
# timer:  1.6319 sec.
# -------------
# Epoch 208/300
# -------------
# (train)
# -------------
# epoch 208 || Epoch_D_Loss:0.0988 ||Epoch_G_Loss:0.0873
# timer:  1.6515 sec.
# -------------
# Epoch 209/300
# -------------
# (train)
# -------------
# epoch 209 || Epoch_D_Loss:0.1069 ||Epoch_G_Loss:0.1131
# timer:  1.6395 sec.
# -------------
# Epoch 210/300
# -------------
# (train)
# -------------
# epoch 210 || Epoch_D_Loss:0.0920 ||Epoch_G_Loss:0.1061
# timer:  1.6339 sec.
# -------------
# Epoch 211/300
# -------------
# (train)
# -------------
# epoch 211 || Epoch_D_Loss:0.1007 ||Epoch_G_Loss:0.1180
# timer:  1.6253 sec.
# -------------
# Epoch 212/300
# -------------
# (train)
# -------------
# epoch 212 || Epoch_D_Loss:0.0946 ||Epoch_G_Loss:0.1102
# timer:  1.6411 sec.
# -------------
# Epoch 213/300
# -------------
# (train)
# -------------
# epoch 213 || Epoch_D_Loss:0.1004 ||Epoch_G_Loss:0.1191
# timer:  1.6268 sec.
# -------------
# Epoch 214/300
# -------------
# (train)
# -------------
# epoch 214 || Epoch_D_Loss:0.0969 ||Epoch_G_Loss:0.1191
# timer:  1.6440 sec.
# -------------
# Epoch 215/300
# -------------
# (train)
# -------------
# epoch 215 || Epoch_D_Loss:0.0863 ||Epoch_G_Loss:0.1174
# timer:  1.6217 sec.
# -------------
# Epoch 216/300
# -------------
# (train)
# -------------
# epoch 216 || Epoch_D_Loss:0.0980 ||Epoch_G_Loss:0.1392
# timer:  1.6349 sec.
# -------------
# Epoch 217/300
# -------------
# (train)
# -------------
# epoch 217 || Epoch_D_Loss:0.0974 ||Epoch_G_Loss:0.1168
# timer:  1.6384 sec.
# -------------
# Epoch 218/300
# -------------
# (train)
# -------------
# epoch 218 || Epoch_D_Loss:0.0937 ||Epoch_G_Loss:0.1240
# timer:  1.6256 sec.
# -------------
# Epoch 219/300
# -------------
# (train)
# -------------
# epoch 219 || Epoch_D_Loss:0.0877 ||Epoch_G_Loss:0.1153
# timer:  1.6308 sec.
# -------------
# Epoch 220/300
# -------------
# (train)
# -------------
# epoch 220 || Epoch_D_Loss:0.0899 ||Epoch_G_Loss:0.1461
# timer:  1.6374 sec.
# -------------
# Epoch 221/300
# -------------
# (train)
# -------------
# epoch 221 || Epoch_D_Loss:0.0711 ||Epoch_G_Loss:0.1410
# timer:  1.6291 sec.
# -------------
# Epoch 222/300
# -------------
# (train)
# -------------
# epoch 222 || Epoch_D_Loss:0.0957 ||Epoch_G_Loss:0.1509
# timer:  1.6262 sec.
# -------------
# Epoch 223/300
# -------------
# (train)
# -------------
# epoch 223 || Epoch_D_Loss:0.0904 ||Epoch_G_Loss:0.1103
# timer:  1.6264 sec.
# -------------
# Epoch 224/300
# -------------
# (train)
# -------------
# epoch 224 || Epoch_D_Loss:0.0977 ||Epoch_G_Loss:0.1288
# timer:  1.6323 sec.
# -------------
# Epoch 225/300
# -------------
# (train)
# -------------
# epoch 225 || Epoch_D_Loss:0.0889 ||Epoch_G_Loss:0.1277
# timer:  1.6304 sec.
# -------------
# Epoch 226/300
# -------------
# (train)
# -------------
# epoch 226 || Epoch_D_Loss:0.0769 ||Epoch_G_Loss:0.1282
# timer:  1.6316 sec.
# -------------
# Epoch 227/300
# -------------
# (train)
# -------------
# epoch 227 || Epoch_D_Loss:0.0837 ||Epoch_G_Loss:0.1343
# timer:  1.6273 sec.
# -------------
# Epoch 228/300
# -------------
# (train)
# -------------
# epoch 228 || Epoch_D_Loss:0.0753 ||Epoch_G_Loss:0.1323
# timer:  1.6308 sec.
# -------------
# Epoch 229/300
# -------------
# (train)
# -------------
# epoch 229 || Epoch_D_Loss:0.0915 ||Epoch_G_Loss:0.1500
# timer:  1.6345 sec.
# -------------
# Epoch 230/300
# -------------
# (train)
# -------------
# epoch 230 || Epoch_D_Loss:0.0720 ||Epoch_G_Loss:0.1290
# timer:  1.6244 sec.
# -------------
# Epoch 231/300
# -------------
# (train)
# -------------
# epoch 231 || Epoch_D_Loss:0.0823 ||Epoch_G_Loss:0.1430
# timer:  1.6073 sec.
# -------------
# Epoch 232/300
# -------------
# (train)
# -------------
# epoch 232 || Epoch_D_Loss:0.0694 ||Epoch_G_Loss:0.1395
# timer:  1.6150 sec.
# -------------
# Epoch 233/300
# -------------
# (train)
# -------------
# epoch 233 || Epoch_D_Loss:0.0866 ||Epoch_G_Loss:0.1433
# timer:  1.6201 sec.
# -------------
# Epoch 234/300
# -------------
# (train)
# -------------
# epoch 234 || Epoch_D_Loss:0.0851 ||Epoch_G_Loss:0.1513
# timer:  1.6424 sec.
# -------------
# Epoch 235/300
# -------------
# (train)
# -------------
# epoch 235 || Epoch_D_Loss:0.0698 ||Epoch_G_Loss:0.1380
# timer:  1.6191 sec.
# -------------
# Epoch 236/300
# -------------
# (train)
# -------------
# epoch 236 || Epoch_D_Loss:0.0813 ||Epoch_G_Loss:0.1555
# timer:  1.6381 sec.
# -------------
# Epoch 237/300
# -------------
# (train)
# -------------
# epoch 237 || Epoch_D_Loss:0.0658 ||Epoch_G_Loss:0.1517
# timer:  1.6229 sec.
# -------------
# Epoch 238/300
# -------------
# (train)
# -------------
# epoch 238 || Epoch_D_Loss:0.0703 ||Epoch_G_Loss:0.1560
# timer:  1.6110 sec.
# -------------
# Epoch 239/300
# -------------
# (train)
# -------------
# epoch 239 || Epoch_D_Loss:0.0719 ||Epoch_G_Loss:0.1358
# timer:  1.6433 sec.
# -------------
# Epoch 240/300
# -------------
# (train)
# -------------
# epoch 240 || Epoch_D_Loss:0.0713 ||Epoch_G_Loss:0.1559
# timer:  1.6281 sec.
# -------------
# Epoch 241/300
# -------------
# (train)
# -------------
# epoch 241 || Epoch_D_Loss:0.0666 ||Epoch_G_Loss:0.1494
# timer:  1.6224 sec.
# -------------
# Epoch 242/300
# -------------
# (train)
# -------------
# epoch 242 || Epoch_D_Loss:0.0487 ||Epoch_G_Loss:0.1742
# timer:  1.6183 sec.
# -------------
# Epoch 243/300
# -------------
# (train)
# -------------
# epoch 243 || Epoch_D_Loss:0.0687 ||Epoch_G_Loss:0.1440
# timer:  1.6257 sec.
# -------------
# Epoch 244/300
# -------------
# (train)
# -------------
# epoch 244 || Epoch_D_Loss:0.0574 ||Epoch_G_Loss:0.1746
# timer:  1.6352 sec.
# -------------
# Epoch 245/300
# -------------
# (train)
# -------------
# epoch 245 || Epoch_D_Loss:0.0653 ||Epoch_G_Loss:0.1520
# timer:  1.6208 sec.
# -------------
# Epoch 246/300
# -------------
# (train)
# -------------
# epoch 246 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.1412
# timer:  1.6217 sec.
# -------------
# Epoch 247/300
# -------------
# (train)
# -------------
# epoch 247 || Epoch_D_Loss:0.0593 ||Epoch_G_Loss:0.1388
# timer:  1.6326 sec.
# -------------
# Epoch 248/300
# -------------
# (train)
# -------------
# epoch 248 || Epoch_D_Loss:0.0691 ||Epoch_G_Loss:0.1784
# timer:  1.6331 sec.
# -------------
# Epoch 249/300
# -------------
# (train)
# -------------
# epoch 249 || Epoch_D_Loss:0.0720 ||Epoch_G_Loss:0.1697
# timer:  1.6439 sec.
# -------------
# Epoch 250/300
# -------------
# (train)
# -------------
# epoch 250 || Epoch_D_Loss:0.0597 ||Epoch_G_Loss:0.1653
# timer:  1.6262 sec.
# -------------
# Epoch 251/300
# -------------
# (train)
# -------------
# epoch 251 || Epoch_D_Loss:0.0626 ||Epoch_G_Loss:0.1569
# timer:  1.6283 sec.
# -------------
# Epoch 252/300
# -------------
# (train)
# -------------
# epoch 252 || Epoch_D_Loss:0.0448 ||Epoch_G_Loss:0.1489
# timer:  1.6284 sec.
# -------------
# Epoch 253/300
# -------------
# (train)
# -------------
# epoch 253 || Epoch_D_Loss:0.0542 ||Epoch_G_Loss:0.1717
# timer:  1.6152 sec.
# -------------
# Epoch 254/300
# -------------
# (train)
# -------------
# epoch 254 || Epoch_D_Loss:0.0739 ||Epoch_G_Loss:0.1789
# timer:  1.6337 sec.
# -------------
# Epoch 255/300
# -------------
# (train)
# -------------
# epoch 255 || Epoch_D_Loss:0.0569 ||Epoch_G_Loss:0.1589
# timer:  1.6321 sec.
# -------------
# Epoch 256/300
# -------------
# (train)
# -------------
# epoch 256 || Epoch_D_Loss:0.0632 ||Epoch_G_Loss:0.1701
# timer:  1.6205 sec.
# -------------
# Epoch 257/300
# -------------
# (train)
# -------------
# epoch 257 || Epoch_D_Loss:0.0706 ||Epoch_G_Loss:0.1757
# timer:  1.6243 sec.
# -------------
# Epoch 258/300
# -------------
# (train)
# -------------
# epoch 258 || Epoch_D_Loss:0.0588 ||Epoch_G_Loss:0.1678
# timer:  1.6236 sec.
# -------------
# Epoch 259/300
# -------------
# (train)
# -------------
# epoch 259 || Epoch_D_Loss:0.0567 ||Epoch_G_Loss:0.1681
# timer:  1.6338 sec.
# -------------
# Epoch 260/300
# -------------
# (train)
# -------------
# epoch 260 || Epoch_D_Loss:0.0620 ||Epoch_G_Loss:0.1708
# timer:  1.6170 sec.
# -------------
# Epoch 261/300
# -------------
# (train)
# -------------
# epoch 261 || Epoch_D_Loss:0.0466 ||Epoch_G_Loss:0.1816
# timer:  1.6191 sec.
# -------------
# Epoch 262/300
# -------------
# (train)
# -------------
# epoch 262 || Epoch_D_Loss:0.0624 ||Epoch_G_Loss:0.1571
# timer:  1.6337 sec.
# -------------
# Epoch 263/300
# -------------
# (train)
# -------------
# epoch 263 || Epoch_D_Loss:0.0481 ||Epoch_G_Loss:0.1636
# timer:  1.6087 sec.
# -------------
# Epoch 264/300
# -------------
# (train)
# -------------
# epoch 264 || Epoch_D_Loss:0.0569 ||Epoch_G_Loss:0.1798
# timer:  1.6261 sec.
# -------------
# Epoch 265/300
# -------------
# (train)
# -------------
# epoch 265 || Epoch_D_Loss:0.0525 ||Epoch_G_Loss:0.1643
# timer:  1.6184 sec.
# -------------
# Epoch 266/300
# -------------
# (train)
# -------------
# epoch 266 || Epoch_D_Loss:0.0510 ||Epoch_G_Loss:0.1916
# timer:  1.6240 sec.
# -------------
# Epoch 267/300
# -------------
# (train)
# -------------
# epoch 267 || Epoch_D_Loss:0.0603 ||Epoch_G_Loss:0.1632
# timer:  1.6345 sec.
# -------------
# Epoch 268/300
# -------------
# (train)
# -------------
# epoch 268 || Epoch_D_Loss:0.0579 ||Epoch_G_Loss:0.1866
# timer:  1.6125 sec.
# -------------
# Epoch 269/300
# -------------
# (train)
# -------------
# epoch 269 || Epoch_D_Loss:0.0536 ||Epoch_G_Loss:0.1808
# timer:  1.6097 sec.
# -------------
# Epoch 270/300
# -------------
# (train)
# -------------
# epoch 270 || Epoch_D_Loss:0.0517 ||Epoch_G_Loss:0.1864
# timer:  1.6316 sec.
# -------------
# Epoch 271/300
# -------------
# (train)
# -------------
# epoch 271 || Epoch_D_Loss:0.0359 ||Epoch_G_Loss:0.2014
# timer:  1.6042 sec.
# -------------
# Epoch 272/300
# -------------
# (train)
# -------------
# epoch 272 || Epoch_D_Loss:0.0608 ||Epoch_G_Loss:0.2015
# timer:  1.6127 sec.
# -------------
# Epoch 273/300
# -------------
# (train)
# -------------
# epoch 273 || Epoch_D_Loss:0.0548 ||Epoch_G_Loss:0.1737
# timer:  1.6157 sec.
# -------------
# Epoch 274/300
# -------------
# (train)
# -------------
# epoch 274 || Epoch_D_Loss:0.0590 ||Epoch_G_Loss:0.1902
# timer:  1.6081 sec.
# -------------
# Epoch 275/300
# -------------
# (train)
# -------------
# epoch 275 || Epoch_D_Loss:0.0460 ||Epoch_G_Loss:0.1970
# timer:  1.6184 sec.
# -------------
# Epoch 276/300
# -------------
# (train)
# -------------
# epoch 276 || Epoch_D_Loss:0.0553 ||Epoch_G_Loss:0.1690
# timer:  1.6156 sec.
# -------------
# Epoch 277/300
# -------------
# (train)
# -------------
# epoch 277 || Epoch_D_Loss:0.0526 ||Epoch_G_Loss:0.1950
# timer:  1.6187 sec.
# -------------
# Epoch 278/300
# -------------
# (train)
# -------------
# epoch 278 || Epoch_D_Loss:0.0591 ||Epoch_G_Loss:0.1565
# timer:  1.6058 sec.
# -------------
# Epoch 279/300
# -------------
# (train)
# -------------
# epoch 279 || Epoch_D_Loss:0.0435 ||Epoch_G_Loss:0.1988
# timer:  1.6224 sec.
# -------------
# Epoch 280/300
# -------------
# (train)
# -------------
# epoch 280 || Epoch_D_Loss:0.0490 ||Epoch_G_Loss:0.1763
# timer:  1.6216 sec.
# -------------
# Epoch 281/300
# -------------
# (train)
# -------------
# epoch 281 || Epoch_D_Loss:0.0469 ||Epoch_G_Loss:0.2027
# timer:  1.6376 sec.
# -------------
# Epoch 282/300
# -------------
# (train)
# -------------
# epoch 282 || Epoch_D_Loss:0.0378 ||Epoch_G_Loss:0.2116
# timer:  1.6061 sec.
# -------------
# Epoch 283/300
# -------------
# (train)
# -------------
# epoch 283 || Epoch_D_Loss:0.0342 ||Epoch_G_Loss:0.1859
# timer:  1.6383 sec.
# -------------
# Epoch 284/300
# -------------
# (train)
# -------------
# epoch 284 || Epoch_D_Loss:0.0633 ||Epoch_G_Loss:0.2197
# timer:  1.6126 sec.
# -------------
# Epoch 285/300
# -------------
# (train)
# -------------
# epoch 285 || Epoch_D_Loss:0.0368 ||Epoch_G_Loss:0.2217
# timer:  1.6066 sec.
# -------------
# Epoch 286/300
# -------------
# (train)
# -------------
# epoch 286 || Epoch_D_Loss:0.0448 ||Epoch_G_Loss:0.1944
# timer:  1.6219 sec.
# -------------
# Epoch 287/300
# -------------
# (train)
# -------------
# epoch 287 || Epoch_D_Loss:0.0554 ||Epoch_G_Loss:0.2074
# timer:  1.6323 sec.
# -------------
# Epoch 288/300
# -------------
# (train)
# -------------
# epoch 288 || Epoch_D_Loss:0.0438 ||Epoch_G_Loss:0.2165
# timer:  1.6140 sec.
# -------------
# Epoch 289/300
# -------------
# (train)
# -------------
# epoch 289 || Epoch_D_Loss:0.0424 ||Epoch_G_Loss:0.2063
# timer:  1.6358 sec.
# -------------
# Epoch 290/300
# -------------
# (train)
# -------------
# epoch 290 || Epoch_D_Loss:0.0454 ||Epoch_G_Loss:0.2144
# timer:  1.6100 sec.
# -------------
# Epoch 291/300
# -------------
# (train)
# -------------
# epoch 291 || Epoch_D_Loss:0.0281 ||Epoch_G_Loss:0.1957
# timer:  1.6076 sec.
# -------------
# Epoch 292/300
# -------------
# (train)
# -------------
# epoch 292 || Epoch_D_Loss:0.0530 ||Epoch_G_Loss:0.2198
# timer:  1.6239 sec.
# -------------
# Epoch 293/300
# -------------
# (train)
# -------------
# epoch 293 || Epoch_D_Loss:0.0298 ||Epoch_G_Loss:0.2155
# timer:  1.6126 sec.
# -------------
# Epoch 294/300
# -------------
# (train)
# -------------
# epoch 294 || Epoch_D_Loss:0.0418 ||Epoch_G_Loss:0.2204
# timer:  1.6131 sec.
# -------------
# Epoch 295/300
# -------------
# (train)
# -------------
# epoch 295 || Epoch_D_Loss:0.0401 ||Epoch_G_Loss:0.2238
# timer:  1.6106 sec.
# -------------
# Epoch 296/300
# -------------
# (train)
# -------------
# epoch 296 || Epoch_D_Loss:0.0342 ||Epoch_G_Loss:0.2238
# timer:  1.6145 sec.
# -------------
# Epoch 297/300
# -------------
# (train)
# -------------
# epoch 297 || Epoch_D_Loss:0.0455 ||Epoch_G_Loss:0.2054
# timer:  1.6003 sec.
# -------------
# Epoch 298/300
# -------------
# (train)
# -------------
# epoch 298 || Epoch_D_Loss:0.0391 ||Epoch_G_Loss:0.2284
# timer:  1.6289 sec.
# -------------
# Epoch 299/300
# -------------
# (train)
# -------------
# epoch 299 || Epoch_D_Loss:0.0366 ||Epoch_G_Loss:0.2032
# timer:  1.6280 sec.

# %%
# 생성 이미지와 훈련 데이터를 시각화

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 입력 난수 생성
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 화상 생성
G_update.eval()
fake_images, am1, am2 = G_update(fixed_z.to(device))

# 훈련 데이터
batch_iterator = iter(train_dataloader)  # 반복자로 변환
imges = next(batch_iterator)  # 1번째 요소를 꺼낸다


# 출력
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 상단에 훈련 데이터를,
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 하단에 생성 데이터를 표시한다
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %%
# Attentiom Map 출력
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):

    # 상단에 생성한 이미지 데이터를 표시
    plt.subplot(2, 5, i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

    # 하단에 Attention Map1 이미지 중앙의 픽셀 데이터를 표시
    plt.subplot(2, 5, 5+i+1)
    am = am1[i].view(16, 16, 16, 16)
    am = am[7][7]  # 중앙에 주목
    plt.imshow(am.cpu().detach().numpy(), 'Blues')
